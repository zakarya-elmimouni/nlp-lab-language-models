# %% [markdown]
# # NLP Lab: Language Models
#
# In this lab, we will build the main components of the GPT-2 model and train a small model on poems by Victor Hugo.
#
# The questions are included in this notebook. To run the training, you will need to modify the `gpt_single_head.py` file, which is also available in the Git repository.
#
# ## Data
#
# The training data consists of a collection of poems by Victor Hugo, sourced from [gutenberg.org](https://www.gutenberg.org/). The dataset is available in the `data` directory.
#
# To reduce model complexity, we will model the text at the character level. Typically, language models process sequences of subwords using [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) such as BPE, SentencePiece, or WordPiece.
#
# #### Questions:
# - Using [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), display the number of unique characters in the text and the frequency of each character.

# %%
import collections
from collections import Counter

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE

###

counter = Counter(text)
chars = sorted(counter.keys())

print(f'Number of character in counter: {sum(counter.values())}')
print(f'{len(chars)} different characters')
print(counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encoding / Decoding
#
# To transform the text into a vector for the neural network, each character must be encoded as an integer.
#
# The following functions perform the encoding and decoding of characters:

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Train/Validation Split
#
# Since the goal is to predict poems, the lines should not be shuffled randomly. Instead, we must preserve the order of the lines in the text and take only the first 90% for training, while using the remaining 10% to monitor learning.
#
# #### Questions:
# - Split the data into `train_data` (90%) and `val_data` (10%) using slicing on the dataset.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
# first 90% will be train, rest val
split_idx = int(0.9 * len(data))

# Split the data
train_data = data[:split_idx]
val_data = data[split_idx:]

print(f'Train data length: {len(train_data)}')
print(f'Validation data length: {len(val_data)}')
###
# Out:
# Train data length: 256699
# Validation data length: 28523

# %% [markdown]
# ### Context
#
# The language model has a parameter that defines the maximum context size to consider when predicting the next character. This context is called `block_size`. The training data consists of sequences of consecutive characters, randomly sampled from the training set, with a length of `block_size`.
#
# If the starting character of the sequence is `i`, then the context sequence is:
# ```python
# x = data[i:i+block_size]
# ```
# And the target value to predict at each position in the context is the next character:
# ```python
# y = data[i+1:i+block_size+1]
# ```

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([249008])
# context is >n< target is >e<
# context is >ne< target is > <
# context is >ne < target is >e<
# context is >ne e< target is >n<
# context is >ne en< target is > <
# context is >ne en < target is >d<
# context is >ne en d< target is >e<
# context is >ne en de< target is >v<

# %% [markdown]
# ### Defining Batches
#
# The training batches consist of multiple character sequences randomly sampled from `train_data`. To randomly select a sequence for the batch, we need to randomly pick a starting point in `train_data` and extract the following `block_size` characters. When selecting the starting point, ensure that there are enough characters remaining after it to form a full sequence of `block_size` characters.
#
# #### Questions:
# - Create the batches `x` by selecting `batch_size` sequences of length `block_size` starting from a randomly chosen index `i`. Stack the examples using `torch.stack`.
# - Create the batches `y` by adding the next character following each sequence in `x`. Stack the examples using `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    starting_points = torch.randint(len(data) - block_size, (batch_size,))
    
    x = torch.stack([data[i:i+block_size] for i in starting_points])
    y = torch.stack([data[i+1:i+block_size+1] for i in starting_points])
    
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y
# Out:
# Using device: cuda

# %% [markdown]
# ### First Model: A Bigram Model
#
# The first model we will implement is a bigram model. It predicts the next character based only on the current character. This model can be stored in a simple matrix: for each character (row), we store the probability distribution over all possible next characters (columns). This can be implemented using a simple [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html) layer in PyTorch.
#
# #### Questions:
# - In the constructor, define an Embedding layer of size `vocab_size × vocab_size`.
# - In the `forward` method, apply the embedding layer to the batch of indices (`x`).
# - In the `forward` method, define the loss as `cross_entropy` between the predictions and the target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)

        ## 
        
    def forward(self, idx, targets=None):
        # idx and targets are both (Batch, Time) tensor of integers
        logits = self.token_embedding_table(idx)  # (Batch, Time, Channel)
        
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch * Time, Channels)
            targets = targets.view(Batch * Time)
            
            # negative log likelihood between prediction and target
            loss = nn.functional.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx
vocab_size=101
model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# ### Model Before Training
#
# At this stage, the model has not yet been trained—it has only been initialized. However, we can already compute the loss on a random batch. Since the weights are initialized with a normal distribution \( N(0,1) \) for each dimension, the expected loss after initialization should be close to `-ln(1/vocab_size)`, as the entropy is maximal.

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'Expected loss {-math.log(1.0/vocab_size)}')
print (f'Computed loss {loss}')
# Out:
# torch.Size([32, 101])
# Expected loss 4.61512051684126
# Computed loss 4.9072675704956055

# %% [markdown]
# ### Using the Model for Prediction
#
# To use the model for prediction, we need to provide an initial character to start the sequence—this is called the prompt. In our case, we can initialize the generation with the newline character (`\n`) to start a new sentence.
#
# #### Questions:
# - Create a prompt as a tensor of size `(1,1)` containing the integer corresponding to the character `\n`.
# - Generate a sequence of 100 characters from this prompt using the functions `m.generate` and `decode`.
# - How does the generated sentence look?

# %%
# Create a prompt as a tensor of size (1,1) containing the integer corresponding to the character '\n'
prompt = torch.tensor([[stoi['\n']]], dtype=torch.long).to(device)

# Generate a sequence of 100 characters from this prompt
generated_sequence = m.generate(prompt, max_new_tokens=100)

# Decode the generated sequence to get the string
generated_text = decode(generated_sequence[0].tolist())

print(generated_text)
# Out:
# aG:I
# aéPwÉEl!è2YpÎpKIuU.ôZUwZ_Èt«bN_;c.8(hO1ÀÀhZVèÂmeôW!5«8XRTkRB·3?KÔ)[lmSËûÈ9àxIJxIêScfî-EPuaFR2ÊÆ

# %% [markdown]
# completly non sense sentence!

# %% [markdown]
# ### Training
#
# For training, we use the [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) optimizer with a learning rate of `1e-3`. Each training iteration consists of the following steps:
#
# - Generate a batch
# - Apply the neural network (forward pass) and compute the loss: `model(xb, yb)`
# - Compute the gradient (after resetting accumulated gradients): `loss.backward()`
# - Update the parameters: `optimizer.step()`

# %%
max_iters = 10000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.0740, val loss 5.1200
# step 10: train loss 5.0470, val loss 5.1134
# step 20: train loss 5.0617, val loss 5.1469
# step 30: train loss 5.0472, val loss 5.0305
# step 40: train loss 4.9784, val loss 5.1064
# step 50: train loss 5.0134, val loss 5.1287
# step 60: train loss 5.0903, val loss 5.0338
# step 70: train loss 4.9986, val loss 5.0643
# step 80: train loss 5.0706, val loss 5.0360
# step 90: train loss 5.0285, val loss 4.9473
# step 100: train loss 5.0316, val loss 5.0384
# step 110: train loss 5.0336, val loss 4.9459
# step 120: train loss 4.9957, val loss 4.9661
# step 130: train loss 4.9817, val loss 4.9911
# step 140: train loss 5.0004, val loss 4.9792
# step 150: train loss 4.9430, val loss 4.9912
# step 160: train loss 4.9083, val loss 4.9491
# step 170: train loss 4.9162, val loss 4.9848
# step 180: train loss 4.9249, val loss 4.9118
# step 190: train loss 4.8650, val loss 4.9521
# step 200: train loss 4.9079, val loss 4.9385
# step 210: train loss 4.9454, val loss 4.8505
# step 220: train loss 4.9226, val loss 4.9381
# step 230: train loss 4.9087, val loss 4.9355
# step 240: train loss 4.9777, val loss 4.9093
# step 250: train loss 4.8520, val loss 4.9119
# step 260: train loss 4.8469, val loss 4.8371
# step 270: train loss 4.9034, val loss 4.8866
# step 280: train loss 4.8835, val loss 4.8154
# step 290: train loss 4.7530, val loss 4.8276
# step 300: train loss 4.8379, val loss 4.9146
# step 310: train loss 4.8754, val loss 4.8854
# step 320: train loss 4.8170, val loss 4.8961
# step 330: train loss 4.7564, val loss 4.8078
# step 340: train loss 4.8324, val loss 4.8445
# step 350: train loss 4.7937, val loss 4.8082
# step 360: train loss 4.7584, val loss 4.8816
# step 370: train loss 4.6834, val loss 4.7726
# step 380: train loss 4.7843, val loss 4.7790
# step 390: train loss 4.6922, val loss 4.7813
# step 400: train loss 4.7740, val loss 4.7828
# step 410: train loss 4.7280, val loss 4.8112
# step 420: train loss 4.6750, val loss 4.8152
# step 430: train loss 4.7324, val loss 4.7319
# step 440: train loss 4.7383, val loss 4.7136
# step 450: train loss 4.7428, val loss 4.7378
# step 460: train loss 4.6948, val loss 4.7325
# step 470: train loss 4.6469, val loss 4.6699
# step 480: train loss 4.6675, val loss 4.6879
# step 490: train loss 4.6847, val loss 4.7680
# step 500: train loss 4.6148, val loss 4.7292
# step 510: train loss 4.6724, val loss 4.7108
# step 520: train loss 4.6648, val loss 4.6999
# step 530: train loss 4.5705, val loss 4.6203
# step 540: train loss 4.6193, val loss 4.6383
# step 550: train loss 4.5707, val loss 4.6639
# step 560: train loss 4.6691, val loss 4.6394
# step 570: train loss 4.6342, val loss 4.6923
# step 580: train loss 4.6055, val loss 4.6354
# step 590: train loss 4.6267, val loss 4.6098
# step 600: train loss 4.6188, val loss 4.6790
# step 610: train loss 4.5876, val loss 4.5844
# step 620: train loss 4.5615, val loss 4.6899
# step 630: train loss 4.5789, val loss 4.6641
# step 640: train loss 4.5752, val loss 4.6064
# step 650: train loss 4.5389, val loss 4.5886
# step 660: train loss 4.4724, val loss 4.5562
# step 670: train loss 4.5636, val loss 4.5980
# step 680: train loss 4.5461, val loss 4.6104
# step 690: train loss 4.5621, val loss 4.5350
# step 700: train loss 4.5157, val loss 4.5868
# step 710: train loss 4.4509, val loss 4.5317
# step 720: train loss 4.5385, val loss 4.4549
# step 730: train loss 4.5179, val loss 4.5966
# step 740: train loss 4.4693, val loss 4.5054
# step 750: train loss 4.4820, val loss 4.4720
# step 760: train loss 4.4245, val loss 4.4557
# step 770: train loss 4.4142, val loss 4.4527
# step 780: train loss 4.4487, val loss 4.4611
# step 790: train loss 4.4680, val loss 4.4434
# step 800: train loss 4.5068, val loss 4.5058
# step 810: train loss 4.4450, val loss 4.4633
# step 820: train loss 4.4482, val loss 4.4633
# step 830: train loss 4.4648, val loss 4.3958
# step 840: train loss 4.4458, val loss 4.4470
# step 850: train loss 4.3794, val loss 4.4947
# step 860: train loss 4.3739, val loss 4.4676
# step 870: train loss 4.4282, val loss 4.4527
# step 880: train loss 4.3905, val loss 4.3894
# step 890: train loss 4.3757, val loss 4.4101
# step 900: train loss 4.4142, val loss 4.4590
# step 910: train loss 4.4360, val loss 4.4279
# step 920: train loss 4.3593, val loss 4.2962
# step 930: train loss 4.3947, val loss 4.3724
# step 940: train loss 4.3494, val loss 4.3904
# step 950: train loss 4.3110, val loss 4.3674
# step 960: train loss 4.3090, val loss 4.3626
# step 970: train loss 4.3305, val loss 4.3071
# step 980: train loss 4.3041, val loss 4.3800
# step 990: train loss 4.2953, val loss 4.4060
# step 1000: train loss 4.3172, val loss 4.3459
# step 1010: train loss 4.2902, val loss 4.3433
# step 1020: train loss 4.2894, val loss 4.3030
# step 1030: train loss 4.2609, val loss 4.3573
# step 1040: train loss 4.2927, val loss 4.3697
# step 1050: train loss 4.2417, val loss 4.2783
# step 1060: train loss 4.2818, val loss 4.3259
# step 1070: train loss 4.2862, val loss 4.3210
# step 1080: train loss 4.2552, val loss 4.2772
# step 1090: train loss 4.2712, val loss 4.3289
# step 1100: train loss 4.2371, val loss 4.2984
# step 1110: train loss 4.1501, val loss 4.2719
# step 1120: train loss 4.1815, val loss 4.2308
# step 1130: train loss 4.1698, val loss 4.2487
# step 1140: train loss 4.2687, val loss 4.3119
# step 1150: train loss 4.1970, val loss 4.2625
# step 1160: train loss 4.2074, val loss 4.2871
# step 1170: train loss 4.1610, val loss 4.2635
# step 1180: train loss 4.2491, val loss 4.2690
# step 1190: train loss 4.2344, val loss 4.2501
# step 1200: train loss 4.1105, val loss 4.2182
# step 1210: train loss 4.1223, val loss 4.2093
# step 1220: train loss 4.1679, val loss 4.1871
# step 1230: train loss 4.1230, val loss 4.2184
# step 1240: train loss 4.1168, val loss 4.1812
# step 1250: train loss 4.1604, val loss 4.2409
# step 1260: train loss 4.0582, val loss 4.1495
# step 1270: train loss 4.0727, val loss 4.1595
# step 1280: train loss 4.1493, val loss 4.2252
# step 1290: train loss 4.0449, val loss 4.0999
# step 1300: train loss 4.0968, val loss 4.0973
# step 1310: train loss 4.1149, val loss 4.1431
# step 1320: train loss 4.1049, val loss 4.1797
# step 1330: train loss 4.0812, val loss 4.1663
# step 1340: train loss 4.0856, val loss 4.0583
# step 1350: train loss 4.0744, val loss 4.1043
# step 1360: train loss 4.0928, val loss 4.0816
# step 1370: train loss 4.0463, val loss 4.1024
# step 1380: train loss 4.1105, val loss 4.1450
# step 1390: train loss 4.0375, val loss 4.0058
# step 1400: train loss 4.0367, val loss 4.0968
# step 1410: train loss 4.0656, val loss 4.1632
# step 1420: train loss 3.9702, val loss 4.0778
# step 1430: train loss 4.0320, val loss 4.1484
# step 1440: train loss 4.0453, val loss 4.0580
# step 1450: train loss 4.0007, val loss 4.1090
# step 1460: train loss 4.0534, val loss 4.1191
# step 1470: train loss 3.9945, val loss 4.0671
# step 1480: train loss 4.0896, val loss 4.1005
# step 1490: train loss 3.9638, val loss 4.0197
# step 1500: train loss 4.0314, val loss 3.9757
# step 1510: train loss 3.9627, val loss 3.9672
# step 1520: train loss 3.9662, val loss 4.0273
# step 1530: train loss 3.9200, val loss 4.0255
# step 1540: train loss 4.0042, val loss 4.0237
# step 1550: train loss 3.9836, val loss 3.9304
# step 1560: train loss 3.9328, val loss 4.0424
# step 1570: train loss 3.9609, val loss 4.0277
# step 1580: train loss 3.8990, val loss 3.9651
# step 1590: train loss 4.0364, val loss 4.0391
# step 1600: train loss 4.0052, val loss 3.9531
# step 1610: train loss 3.9473, val loss 3.9539
# step 1620: train loss 3.9648, val loss 3.9001
# step 1630: train loss 3.9509, val loss 3.9771
# step 1640: train loss 3.8669, val loss 3.9696
# step 1650: train loss 3.9563, val loss 4.0043
# step 1660: train loss 3.9175, val loss 3.9673
# step 1670: train loss 3.8666, val loss 3.9870
# step 1680: train loss 3.8457, val loss 4.1182
# step 1690: train loss 3.8753, val loss 3.9549
# step 1700: train loss 3.8827, val loss 3.9260
# step 1710: train loss 3.8974, val loss 3.9979
# step 1720: train loss 3.9539, val loss 3.9065
# step 1730: train loss 3.9082, val loss 3.9427
# step 1740: train loss 3.8612, val loss 3.9313
# step 1750: train loss 3.8872, val loss 4.0331
# step 1760: train loss 3.8531, val loss 3.8175
# step 1770: train loss 3.8160, val loss 3.9543
# step 1780: train loss 3.8912, val loss 3.8469
# step 1790: train loss 3.7989, val loss 3.9081
# step 1800: train loss 3.9385, val loss 3.9185
# step 1810: train loss 3.8346, val loss 3.8525
# step 1820: train loss 3.7654, val loss 3.9294
# step 1830: train loss 3.8326, val loss 3.8704
# step 1840: train loss 3.7825, val loss 3.8053
# step 1850: train loss 3.8390, val loss 3.8841
# step 1860: train loss 3.8421, val loss 3.8229
# step 1870: train loss 3.7844, val loss 3.9708
# step 1880: train loss 3.7912, val loss 3.8125
# step 1890: train loss 3.7902, val loss 3.8555
# step 1900: train loss 3.7230, val loss 3.7767
# step 1910: train loss 3.7765, val loss 3.7441
# step 1920: train loss 3.7897, val loss 3.8585
# step 1930: train loss 3.7708, val loss 3.7845
# step 1940: train loss 3.7362, val loss 3.8406
# step 1950: train loss 3.7396, val loss 3.8074
# step 1960: train loss 3.6879, val loss 3.7807
# step 1970: train loss 3.7635, val loss 3.7702
# step 1980: train loss 3.7005, val loss 3.7913
# step 1990: train loss 3.7495, val loss 3.7738
# step 2000: train loss 3.8017, val loss 3.7973
# step 2010: train loss 3.7364, val loss 3.7253
# step 2020: train loss 3.7450, val loss 3.7140
# step 2030: train loss 3.7001, val loss 3.7331
# step 2040: train loss 3.7539, val loss 3.7780
# step 2050: train loss 3.6417, val loss 3.7038
# step 2060: train loss 3.6662, val loss 3.7466
# step 2070: train loss 3.7030, val loss 3.7795
# step 2080: train loss 3.6705, val loss 3.7419
# step 2090: train loss 3.7082, val loss 3.7513
# step 2100: train loss 3.6561, val loss 3.7730
# step 2110: train loss 3.6138, val loss 3.7409
# step 2120: train loss 3.7379, val loss 3.7764
# step 2130: train loss 3.6578, val loss 3.7769
# step 2140: train loss 3.6146, val loss 3.7730
# step 2150: train loss 3.6871, val loss 3.6551
# step 2160: train loss 3.6987, val loss 3.7076
# step 2170: train loss 3.6625, val loss 3.7565
# step 2180: train loss 3.5772, val loss 3.6876
# step 2190: train loss 3.5490, val loss 3.7455
# step 2200: train loss 3.6307, val loss 3.6565
# step 2210: train loss 3.5795, val loss 3.6202
# step 2220: train loss 3.6370, val loss 3.7096
# step 2230: train loss 3.5958, val loss 3.7910
# step 2240: train loss 3.6532, val loss 3.6729
# step 2250: train loss 3.6105, val loss 3.6867
# step 2260: train loss 3.5260, val loss 3.6473
# step 2270: train loss 3.6722, val loss 3.7242
# step 2280: train loss 3.6061, val loss 3.7210
# step 2290: train loss 3.5929, val loss 3.7175
# step 2300: train loss 3.6010, val loss 3.6399
# step 2310: train loss 3.7219, val loss 3.7246
# step 2320: train loss 3.6513, val loss 3.6454
# step 2330: train loss 3.6111, val loss 3.7511
# step 2340: train loss 3.5416, val loss 3.6136
# step 2350: train loss 3.5904, val loss 3.6378
# step 2360: train loss 3.6509, val loss 3.6045
# step 2370: train loss 3.6263, val loss 3.5511
# step 2380: train loss 3.5164, val loss 3.5807
# step 2390: train loss 3.5108, val loss 3.6165
# step 2400: train loss 3.6505, val loss 3.6409
# step 2410: train loss 3.5269, val loss 3.5561
# step 2420: train loss 3.4913, val loss 3.5697
# step 2430: train loss 3.5474, val loss 3.6123
# step 2440: train loss 3.5531, val loss 3.6381
# step 2450: train loss 3.5986, val loss 3.5956
# step 2460: train loss 3.5315, val loss 3.5756
# step 2470: train loss 3.5736, val loss 3.6276
# step 2480: train loss 3.4507, val loss 3.5532
# step 2490: train loss 3.5131, val loss 3.6427
# step 2500: train loss 3.5787, val loss 3.5632
# step 2510: train loss 3.5085, val loss 3.5523
# step 2520: train loss 3.5223, val loss 3.5387
# step 2530: train loss 3.5024, val loss 3.5738
# step 2540: train loss 3.5218, val loss 3.5709
# step 2550: train loss 3.5425, val loss 3.5410
# step 2560: train loss 3.5138, val loss 3.5897
# step 2570: train loss 3.4670, val loss 3.5311
# step 2580: train loss 3.4119, val loss 3.4399
# step 2590: train loss 3.4543, val loss 3.4482
# step 2600: train loss 3.4534, val loss 3.5587
# step 2610: train loss 3.4861, val loss 3.4725
# step 2620: train loss 3.4323, val loss 3.5097
# step 2630: train loss 3.4612, val loss 3.4871
# step 2640: train loss 3.3968, val loss 3.5851
# step 2650: train loss 3.4420, val loss 3.5226
# step 2660: train loss 3.4944, val loss 3.5140
# step 2670: train loss 3.4230, val loss 3.5798
# step 2680: train loss 3.4984, val loss 3.5054
# step 2690: train loss 3.4295, val loss 3.4154
# step 2700: train loss 3.3460, val loss 3.5355
# step 2710: train loss 3.4006, val loss 3.4345
# step 2720: train loss 3.3853, val loss 3.3707
# step 2730: train loss 3.4103, val loss 3.6021
# step 2740: train loss 3.4627, val loss 3.4382
# step 2750: train loss 3.3294, val loss 3.5814
# step 2760: train loss 3.5028, val loss 3.3426
# step 2770: train loss 3.4750, val loss 3.5342
# step 2780: train loss 3.3691, val loss 3.4560
# step 2790: train loss 3.3977, val loss 3.5169
# step 2800: train loss 3.4254, val loss 3.4975
# step 2810: train loss 3.4465, val loss 3.4319
# step 2820: train loss 3.3850, val loss 3.4724
# step 2830: train loss 3.4356, val loss 3.4082
# step 2840: train loss 3.3980, val loss 3.3958
# step 2850: train loss 3.3359, val loss 3.4664
# step 2860: train loss 3.4304, val loss 3.5559
# step 2870: train loss 3.3073, val loss 3.4920
# step 2880: train loss 3.3775, val loss 3.4238
# step 2890: train loss 3.3512, val loss 3.4075
# step 2900: train loss 3.3338, val loss 3.3323
# step 2910: train loss 3.3360, val loss 3.4490
# step 2920: train loss 3.3108, val loss 3.4510
# step 2930: train loss 3.3113, val loss 3.4358
# step 2940: train loss 3.3048, val loss 3.4684
# step 2950: train loss 3.3944, val loss 3.4563
# step 2960: train loss 3.3549, val loss 3.3799
# step 2970: train loss 3.3087, val loss 3.4146
# step 2980: train loss 3.3088, val loss 3.4403
# step 2990: train loss 3.2757, val loss 3.4053
# step 3000: train loss 3.3585, val loss 3.4146
# step 3010: train loss 3.3461, val loss 3.4047
# step 3020: train loss 3.2770, val loss 3.2803
# step 3030: train loss 3.2874, val loss 3.3884
# step 3040: train loss 3.2997, val loss 3.2584
# step 3050: train loss 3.3692, val loss 3.3485
# step 3060: train loss 3.3240, val loss 3.4795
# step 3070: train loss 3.2979, val loss 3.3717
# step 3080: train loss 3.3086, val loss 3.4716
# step 3090: train loss 3.2913, val loss 3.3295
# step 3100: train loss 3.3036, val loss 3.3901
# step 3110: train loss 3.2622, val loss 3.4443
# step 3120: train loss 3.3364, val loss 3.3875
# step 3130: train loss 3.2956, val loss 3.3560
# step 3140: train loss 3.2456, val loss 3.3083
# step 3150: train loss 3.2850, val loss 3.3229
# step 3160: train loss 3.3326, val loss 3.3614
# step 3170: train loss 3.1404, val loss 3.3574
# step 3180: train loss 3.2973, val loss 3.2503
# step 3190: train loss 3.2185, val loss 3.2699
# step 3200: train loss 3.2504, val loss 3.3689
# step 3210: train loss 3.3191, val loss 3.3163
# step 3220: train loss 3.2110, val loss 3.3030
# step 3230: train loss 3.1979, val loss 3.3305
# step 3240: train loss 3.2735, val loss 3.3527
# step 3250: train loss 3.1588, val loss 3.2496
# step 3260: train loss 3.1936, val loss 3.3386
# step 3270: train loss 3.1798, val loss 3.2827
# step 3280: train loss 3.2043, val loss 3.3228
# step 3290: train loss 3.2590, val loss 3.3614
# step 3300: train loss 3.2090, val loss 3.2528
# step 3310: train loss 3.1489, val loss 3.1858
# step 3320: train loss 3.1889, val loss 3.2649
# step 3330: train loss 3.1661, val loss 3.2778
# step 3340: train loss 3.2331, val loss 3.4546
# step 3350: train loss 3.1667, val loss 3.2713
# step 3360: train loss 3.1540, val loss 3.2191
# step 3370: train loss 3.1636, val loss 3.4020
# step 3380: train loss 3.2517, val loss 3.2337
# step 3390: train loss 3.2310, val loss 3.2389
# step 3400: train loss 3.1531, val loss 3.2838
# step 3410: train loss 3.2031, val loss 3.2238
# step 3420: train loss 3.1844, val loss 3.3469
# step 3430: train loss 3.2155, val loss 3.3473
# step 3440: train loss 3.2161, val loss 3.3673
# step 3450: train loss 3.1981, val loss 3.3456
# step 3460: train loss 3.1990, val loss 3.2342
# step 3470: train loss 3.2443, val loss 3.3048
# step 3480: train loss 3.1649, val loss 3.3168
# step 3490: train loss 3.1809, val loss 3.2856
# step 3500: train loss 3.1553, val loss 3.2347
# step 3510: train loss 3.1909, val loss 3.2983
# step 3520: train loss 3.2242, val loss 3.2125
# step 3530: train loss 3.1686, val loss 3.2204
# step 3540: train loss 3.2346, val loss 3.2200
# step 3550: train loss 3.1611, val loss 3.3072
# step 3560: train loss 3.0337, val loss 3.1544
# step 3570: train loss 3.1370, val loss 3.2043
# step 3580: train loss 3.0882, val loss 3.2273
# step 3590: train loss 3.1549, val loss 3.2191
# step 3600: train loss 3.1286, val loss 3.1808
# step 3610: train loss 3.1557, val loss 3.2090
# step 3620: train loss 3.1713, val loss 3.3364
# step 3630: train loss 3.1100, val loss 3.1763
# step 3640: train loss 3.0854, val loss 3.1734
# step 3650: train loss 3.1885, val loss 3.2315
# step 3660: train loss 3.1740, val loss 3.2895
# step 3670: train loss 3.1085, val loss 3.1736
# step 3680: train loss 3.1014, val loss 3.1281
# step 3690: train loss 3.1110, val loss 3.2113
# step 3700: train loss 3.1339, val loss 3.1032
# step 3710: train loss 3.1464, val loss 3.1682
# step 3720: train loss 3.0892, val loss 3.1642
# step 3730: train loss 3.0640, val loss 3.1201
# step 3740: train loss 3.1646, val loss 3.2400
# step 3750: train loss 3.0825, val loss 3.3201
# step 3760: train loss 3.0423, val loss 3.2673
# step 3770: train loss 3.0664, val loss 3.1487
# step 3780: train loss 3.0878, val loss 3.1209
# step 3790: train loss 3.0899, val loss 3.1817
# step 3800: train loss 3.0682, val loss 3.1950
# step 3810: train loss 3.1225, val loss 3.2098
# step 3820: train loss 3.1803, val loss 3.1940
# step 3830: train loss 3.0822, val loss 3.0138
# step 3840: train loss 3.1027, val loss 3.1324
# step 3850: train loss 3.0937, val loss 3.1261
# step 3860: train loss 3.0499, val loss 3.1355
# step 3870: train loss 3.1753, val loss 3.1603
# step 3880: train loss 3.1078, val loss 3.2189
# step 3890: train loss 3.0722, val loss 3.1863
# step 3900: train loss 3.0456, val loss 3.0645
# step 3910: train loss 3.0189, val loss 3.1280
# step 3920: train loss 3.0863, val loss 3.0715
# step 3930: train loss 3.0851, val loss 3.0609
# step 3940: train loss 3.1074, val loss 3.1378
# step 3950: train loss 3.0244, val loss 3.1715
# step 3960: train loss 3.0978, val loss 3.0702
# step 3970: train loss 3.0254, val loss 3.1106
# step 3980: train loss 3.0039, val loss 3.0508
# step 3990: train loss 3.0678, val loss 3.0646
# step 4000: train loss 3.0051, val loss 3.2103
# step 4010: train loss 2.9986, val loss 3.1333
# step 4020: train loss 2.9899, val loss 3.1647
# step 4030: train loss 3.0067, val loss 3.1257
# step 4040: train loss 3.0465, val loss 3.1605
# step 4050: train loss 3.0234, val loss 3.1080
# step 4060: train loss 2.9816, val loss 3.1066
# step 4070: train loss 3.0470, val loss 3.1174
# step 4080: train loss 3.0013, val loss 3.1139
# step 4090: train loss 3.0591, val loss 3.1848
# step 4100: train loss 3.0443, val loss 3.1164
# step 4110: train loss 2.9921, val loss 3.1512
# step 4120: train loss 3.0383, val loss 3.0017
# step 4130: train loss 3.0160, val loss 3.0773
# step 4140: train loss 2.9872, val loss 3.0822
# step 4150: train loss 2.9064, val loss 3.1058
# step 4160: train loss 2.9524, val loss 3.1321
# step 4170: train loss 3.0367, val loss 3.0599
# step 4180: train loss 3.0524, val loss 3.1104
# step 4190: train loss 3.0104, val loss 3.1402
# step 4200: train loss 2.9928, val loss 3.1139
# step 4210: train loss 3.0666, val loss 3.1197
# step 4220: train loss 2.9834, val loss 3.0859
# step 4230: train loss 2.9715, val loss 3.0283
# step 4240: train loss 3.0116, val loss 3.0094
# step 4250: train loss 2.9388, val loss 3.0545
# step 4260: train loss 3.0489, val loss 3.0083
# step 4270: train loss 2.9249, val loss 3.0686
# step 4280: train loss 2.9199, val loss 3.0953
# step 4290: train loss 2.9007, val loss 3.0061
# step 4300: train loss 2.9676, val loss 3.1337
# step 4310: train loss 3.0129, val loss 3.0630
# step 4320: train loss 2.9834, val loss 3.1180
# step 4330: train loss 3.0029, val loss 3.0489
# step 4340: train loss 3.0076, val loss 3.1145
# step 4350: train loss 2.9917, val loss 3.0124
# step 4360: train loss 2.9975, val loss 3.0935
# step 4370: train loss 2.9303, val loss 3.0863
# step 4380: train loss 2.9452, val loss 3.0829
# step 4390: train loss 2.9597, val loss 3.0524
# step 4400: train loss 2.9595, val loss 3.0065
# step 4410: train loss 2.8926, val loss 3.1124
# step 4420: train loss 2.8864, val loss 3.0588
# step 4430: train loss 2.9051, val loss 3.1120
# step 4440: train loss 2.9083, val loss 3.0018
# step 4450: train loss 2.9516, val loss 3.0267
# step 4460: train loss 2.9430, val loss 3.0419
# step 4470: train loss 3.0393, val loss 3.0990
# step 4480: train loss 2.9132, val loss 3.1203
# step 4490: train loss 2.9743, val loss 3.0470
# step 4500: train loss 2.9681, val loss 2.9897
# step 4510: train loss 2.9878, val loss 3.0450
# step 4520: train loss 2.8858, val loss 3.1279
# step 4530: train loss 2.9586, val loss 3.0141
# step 4540: train loss 2.9052, val loss 3.1096
# step 4550: train loss 2.9446, val loss 2.9260
# step 4560: train loss 2.9795, val loss 3.1164
# step 4570: train loss 2.9486, val loss 3.0804
# step 4580: train loss 2.9494, val loss 3.1200
# step 4590: train loss 2.8839, val loss 3.0500
# step 4600: train loss 2.9323, val loss 2.9701
# step 4610: train loss 2.9126, val loss 2.9660
# step 4620: train loss 2.8029, val loss 3.1217
# step 4630: train loss 2.9518, val loss 3.0858
# step 4640: train loss 2.9566, val loss 2.9723
# step 4650: train loss 2.8566, val loss 3.0812
# step 4660: train loss 2.8851, val loss 3.0097
# step 4670: train loss 2.8848, val loss 3.1131
# step 4680: train loss 2.9421, val loss 3.0340
# step 4690: train loss 2.9103, val loss 3.0540
# step 4700: train loss 2.8819, val loss 3.0165
# step 4710: train loss 2.8753, val loss 2.9069
# step 4720: train loss 2.9510, val loss 2.9852
# step 4730: train loss 2.8428, val loss 2.9846
# step 4740: train loss 2.9755, val loss 2.9074
# step 4750: train loss 2.9397, val loss 3.0202
# step 4760: train loss 2.8287, val loss 2.9304
# step 4770: train loss 2.9091, val loss 2.9604
# step 4780: train loss 2.8411, val loss 2.9743
# step 4790: train loss 2.8701, val loss 3.0076
# step 4800: train loss 2.9778, val loss 3.0661
# step 4810: train loss 2.9026, val loss 3.0709
# step 4820: train loss 2.8958, val loss 3.0433
# step 4830: train loss 2.8658, val loss 2.9711
# step 4840: train loss 2.8097, val loss 2.9938
# step 4850: train loss 2.8269, val loss 3.0762
# step 4860: train loss 2.9739, val loss 2.9960
# step 4870: train loss 2.8999, val loss 2.9288
# step 4880: train loss 2.8597, val loss 2.9632
# step 4890: train loss 2.8904, val loss 2.8341
# step 4900: train loss 2.8325, val loss 2.9865
# step 4910: train loss 2.8815, val loss 2.9568
# step 4920: train loss 2.9934, val loss 2.9850
# step 4930: train loss 2.8948, val loss 2.9556
# step 4940: train loss 2.9275, val loss 3.0333
# step 4950: train loss 2.8778, val loss 3.0070
# step 4960: train loss 2.8356, val loss 3.0062
# step 4970: train loss 2.9013, val loss 2.9564
# step 4980: train loss 2.8094, val loss 2.9538
# step 4990: train loss 2.7683, val loss 2.8831
# step 5000: train loss 2.7761, val loss 2.9710
# step 5010: train loss 2.8968, val loss 2.9132
# step 5020: train loss 2.8515, val loss 3.0413
# step 5030: train loss 2.8246, val loss 2.8926
# step 5040: train loss 2.8242, val loss 2.9025
# step 5050: train loss 2.7900, val loss 2.8746
# step 5060: train loss 2.8293, val loss 3.0821
# step 5070: train loss 2.8468, val loss 2.9667
# step 5080: train loss 2.8682, val loss 3.0081
# step 5090: train loss 2.8149, val loss 3.0037
# step 5100: train loss 2.8297, val loss 2.8986
# step 5110: train loss 2.8162, val loss 2.8384
# step 5120: train loss 2.8445, val loss 2.8784
# step 5130: train loss 2.8200, val loss 2.9270
# step 5140: train loss 2.8049, val loss 2.9316
# step 5150: train loss 2.7881, val loss 2.9579
# step 5160: train loss 2.8546, val loss 2.8284
# step 5170: train loss 2.7745, val loss 3.0159
# step 5180: train loss 2.8835, val loss 2.9402
# step 5190: train loss 2.8522, val loss 2.8365
# step 5200: train loss 2.9104, val loss 3.0488
# step 5210: train loss 2.7478, val loss 2.9157
# step 5220: train loss 2.7976, val loss 2.8752
# step 5230: train loss 2.8432, val loss 2.8806
# step 5240: train loss 2.8007, val loss 2.8186
# step 5250: train loss 2.8980, val loss 2.9211
# step 5260: train loss 2.8054, val loss 2.9147
# step 5270: train loss 2.8984, val loss 2.8719
# step 5280: train loss 2.8288, val loss 2.9237
# step 5290: train loss 2.8614, val loss 2.8400
# step 5300: train loss 2.7371, val loss 2.9533
# step 5310: train loss 2.8453, val loss 2.9228
# step 5320: train loss 2.7506, val loss 2.8530
# step 5330: train loss 2.7721, val loss 2.8458
# step 5340: train loss 2.7706, val loss 2.8581
# step 5350: train loss 2.8223, val loss 2.9437
# step 5360: train loss 2.8909, val loss 2.7136
# step 5370: train loss 2.7807, val loss 2.9158
# step 5380: train loss 2.7022, val loss 2.9033
# step 5390: train loss 2.7685, val loss 2.9511
# step 5400: train loss 2.7694, val loss 2.8827
# step 5410: train loss 2.8825, val loss 2.8686
# step 5420: train loss 2.8732, val loss 2.8629
# step 5430: train loss 2.7685, val loss 2.8976
# step 5440: train loss 2.8463, val loss 2.8086
# step 5450: train loss 2.8217, val loss 2.8291
# step 5460: train loss 2.7295, val loss 2.9712
# step 5470: train loss 2.7450, val loss 2.9591
# step 5480: train loss 2.7848, val loss 2.8854
# step 5490: train loss 2.8026, val loss 2.8951
# step 5500: train loss 2.7313, val loss 2.9081
# step 5510: train loss 2.7645, val loss 2.8730
# step 5520: train loss 2.7875, val loss 2.9217
# step 5530: train loss 2.8498, val loss 2.9005
# step 5540: train loss 2.8249, val loss 2.8243
# step 5550: train loss 2.7754, val loss 2.8833
# step 5560: train loss 2.8959, val loss 2.8536
# step 5570: train loss 2.8114, val loss 2.9606
# step 5580: train loss 2.7680, val loss 2.8914
# step 5590: train loss 2.6985, val loss 2.9195
# step 5600: train loss 2.6925, val loss 2.8926
# step 5610: train loss 2.7633, val loss 2.8559
# step 5620: train loss 2.6868, val loss 2.9042
# step 5630: train loss 2.7544, val loss 2.8074
# step 5640: train loss 2.7768, val loss 2.8761
# step 5650: train loss 2.8208, val loss 2.7727
# step 5660: train loss 2.8154, val loss 2.8957
# step 5670: train loss 2.7286, val loss 2.9120
# step 5680: train loss 2.7512, val loss 2.7759
# step 5690: train loss 2.7635, val loss 2.8798
# step 5700: train loss 2.7255, val loss 2.8218
# step 5710: train loss 2.7448, val loss 2.7254
# step 5720: train loss 2.7639, val loss 2.8509
# step 5730: train loss 2.7031, val loss 2.8952
# step 5740: train loss 2.7604, val loss 2.8849
# step 5750: train loss 2.7572, val loss 2.8234
# step 5760: train loss 2.7607, val loss 2.8091
# step 5770: train loss 2.7055, val loss 2.7310
# step 5780: train loss 2.7493, val loss 2.8959
# step 5790: train loss 2.7554, val loss 2.8611
# step 5800: train loss 2.7100, val loss 2.8057
# step 5810: train loss 2.7151, val loss 2.8082
# step 5820: train loss 2.7577, val loss 2.8513
# step 5830: train loss 2.8065, val loss 2.8163
# step 5840: train loss 2.7387, val loss 2.7559
# step 5850: train loss 2.7336, val loss 2.8722
# step 5860: train loss 2.7682, val loss 2.7321
# step 5870: train loss 2.6600, val loss 2.7747
# step 5880: train loss 2.7301, val loss 2.8752
# step 5890: train loss 2.8022, val loss 2.8435
# step 5900: train loss 2.6520, val loss 2.8042
# step 5910: train loss 2.7780, val loss 2.8647
# step 5920: train loss 2.7354, val loss 2.8603
# step 5930: train loss 2.7295, val loss 2.8742
# step 5940: train loss 2.7513, val loss 2.8072
# step 5950: train loss 2.7178, val loss 2.9042
# step 5960: train loss 2.6919, val loss 2.8481
# step 5970: train loss 2.6958, val loss 2.8994
# step 5980: train loss 2.6768, val loss 2.8316
# step 5990: train loss 2.7574, val loss 2.8413
# step 6000: train loss 2.7524, val loss 2.8629
# step 6010: train loss 2.6502, val loss 2.8135
# step 6020: train loss 2.7204, val loss 2.8276
# step 6030: train loss 2.7078, val loss 2.8871
# step 6040: train loss 2.7466, val loss 2.8329
# step 6050: train loss 2.6982, val loss 2.8224
# step 6060: train loss 2.6448, val loss 2.8625
# step 6070: train loss 2.7133, val loss 2.8144
# step 6080: train loss 2.7171, val loss 2.7548
# step 6090: train loss 2.7248, val loss 2.8748
# step 6100: train loss 2.6259, val loss 2.8453
# step 6110: train loss 2.7480, val loss 2.7686
# step 6120: train loss 2.6905, val loss 2.8077
# step 6130: train loss 2.7672, val loss 2.9296
# step 6140: train loss 2.6885, val loss 2.8497
# step 6150: train loss 2.6830, val loss 2.7711
# step 6160: train loss 2.7399, val loss 2.8434
# step 6170: train loss 2.6363, val loss 2.7236
# step 6180: train loss 2.6648, val loss 2.7840
# step 6190: train loss 2.6758, val loss 2.8569
# step 6200: train loss 2.6437, val loss 2.8366
# step 6210: train loss 2.8279, val loss 2.9304
# step 6220: train loss 2.6541, val loss 2.8873
# step 6230: train loss 2.6159, val loss 2.7819
# step 6240: train loss 2.6571, val loss 2.8260
# step 6250: train loss 2.6244, val loss 2.8243
# step 6260: train loss 2.6983, val loss 2.7684
# step 6270: train loss 2.6419, val loss 2.8203
# step 6280: train loss 2.6229, val loss 2.7598
# step 6290: train loss 2.7770, val loss 2.7563
# step 6300: train loss 2.7476, val loss 2.7725
# step 6310: train loss 2.7557, val loss 2.7869
# step 6320: train loss 2.7641, val loss 2.9797
# step 6330: train loss 2.6948, val loss 2.7546
# step 6340: train loss 2.6836, val loss 2.7330
# step 6350: train loss 2.7361, val loss 2.8322
# step 6360: train loss 2.6975, val loss 2.7996
# step 6370: train loss 2.6668, val loss 2.7127
# step 6380: train loss 2.6583, val loss 2.8084
# step 6390: train loss 2.6436, val loss 2.8300
# step 6400: train loss 2.6541, val loss 2.7592
# step 6410: train loss 2.7325, val loss 2.7807
# step 6420: train loss 2.6701, val loss 2.8013
# step 6430: train loss 2.6760, val loss 2.6682
# step 6440: train loss 2.6314, val loss 2.8378
# step 6450: train loss 2.6740, val loss 2.7413
# step 6460: train loss 2.6562, val loss 2.6916
# step 6470: train loss 2.7489, val loss 2.6941
# step 6480: train loss 2.6710, val loss 2.7537
# step 6490: train loss 2.7038, val loss 2.7639
# step 6500: train loss 2.6453, val loss 2.5811
# step 6510: train loss 2.6183, val loss 2.7332
# step 6520: train loss 2.5961, val loss 2.7275
# step 6530: train loss 2.5516, val loss 2.7347
# step 6540: train loss 2.6864, val loss 2.6873
# step 6550: train loss 2.6694, val loss 2.7112
# step 6560: train loss 2.7123, val loss 2.8380
# step 6570: train loss 2.6264, val loss 2.6654
# step 6580: train loss 2.6699, val loss 2.7460
# step 6590: train loss 2.6737, val loss 2.7807
# step 6600: train loss 2.6727, val loss 2.6946
# step 6610: train loss 2.6472, val loss 2.8556
# step 6620: train loss 2.7343, val loss 2.6809
# step 6630: train loss 2.7266, val loss 2.7206
# step 6640: train loss 2.6727, val loss 2.8325
# step 6650: train loss 2.6682, val loss 2.7892
# step 6660: train loss 2.6460, val loss 2.7370
# step 6670: train loss 2.5879, val loss 2.7809
# step 6680: train loss 2.6261, val loss 2.8031
# step 6690: train loss 2.7344, val loss 2.7113
# step 6700: train loss 2.6449, val loss 2.6993
# step 6710: train loss 2.6011, val loss 2.7754
# step 6720: train loss 2.6331, val loss 2.6097
# step 6730: train loss 2.7465, val loss 2.6420
# step 6740: train loss 2.6212, val loss 2.8227
# step 6750: train loss 2.6338, val loss 2.7799
# step 6760: train loss 2.6873, val loss 2.7328
# step 6770: train loss 2.6992, val loss 2.7966
# step 6780: train loss 2.6251, val loss 2.6343
# step 6790: train loss 2.6129, val loss 2.7603
# step 6800: train loss 2.6715, val loss 2.6570
# step 6810: train loss 2.7567, val loss 2.7241
# step 6820: train loss 2.6706, val loss 2.7065
# step 6830: train loss 2.6512, val loss 2.7839
# step 6840: train loss 2.5903, val loss 2.7343
# step 6850: train loss 2.5982, val loss 2.7058
# step 6860: train loss 2.6425, val loss 2.6529
# step 6870: train loss 2.7288, val loss 2.8546
# step 6880: train loss 2.5446, val loss 2.7474
# step 6890: train loss 2.6230, val loss 2.7564
# step 6900: train loss 2.6704, val loss 2.7996
# step 6910: train loss 2.5983, val loss 2.7250
# step 6920: train loss 2.6245, val loss 2.7541
# step 6930: train loss 2.6116, val loss 2.7077
# step 6940: train loss 2.6161, val loss 2.8150
# step 6950: train loss 2.6065, val loss 2.7349
# step 6960: train loss 2.5476, val loss 2.8160
# step 6970: train loss 2.5753, val loss 2.7809
# step 6980: train loss 2.7490, val loss 2.7926
# step 6990: train loss 2.6513, val loss 2.8135
# step 7000: train loss 2.6730, val loss 2.7624
# step 7010: train loss 2.6905, val loss 2.6844
# step 7020: train loss 2.6011, val loss 2.7373
# step 7030: train loss 2.6679, val loss 2.7757
# step 7040: train loss 2.6401, val loss 2.6226
# step 7050: train loss 2.6092, val loss 2.7848
# step 7060: train loss 2.6713, val loss 2.7509
# step 7070: train loss 2.5998, val loss 2.7038
# step 7080: train loss 2.6160, val loss 2.6211
# step 7090: train loss 2.6492, val loss 2.7490
# step 7100: train loss 2.6345, val loss 2.6982
# step 7110: train loss 2.5662, val loss 2.6546
# step 7120: train loss 2.6321, val loss 2.6304
# step 7130: train loss 2.5532, val loss 2.8449
# step 7140: train loss 2.5971, val loss 2.7198
# step 7150: train loss 2.6138, val loss 2.6572
# step 7160: train loss 2.6191, val loss 2.6305
# step 7170: train loss 2.6330, val loss 2.6812
# step 7180: train loss 2.5589, val loss 2.7629
# step 7190: train loss 2.6595, val loss 2.7846
# step 7200: train loss 2.5953, val loss 2.6729
# step 7210: train loss 2.6922, val loss 2.7916
# step 7220: train loss 2.6227, val loss 2.7362
# step 7230: train loss 2.7076, val loss 2.7527
# step 7240: train loss 2.6877, val loss 2.7978
# step 7250: train loss 2.5985, val loss 2.6564
# step 7260: train loss 2.6928, val loss 2.7398
# step 7270: train loss 2.6346, val loss 2.7393
# step 7280: train loss 2.6725, val loss 2.6898
# step 7290: train loss 2.5618, val loss 2.6749
# step 7300: train loss 2.5837, val loss 2.7669
# step 7310: train loss 2.5742, val loss 2.7392
# step 7320: train loss 2.6280, val loss 2.6572
# step 7330: train loss 2.6472, val loss 2.7117
# step 7340: train loss 2.6457, val loss 2.7303
# step 7350: train loss 2.6319, val loss 2.7798
# step 7360: train loss 2.5533, val loss 2.7294
# step 7370: train loss 2.6436, val loss 2.7270
# step 7380: train loss 2.6094, val loss 2.7368
# step 7390: train loss 2.6656, val loss 2.6249
# step 7400: train loss 2.5552, val loss 2.7563
# step 7410: train loss 2.6115, val loss 2.7357
# step 7420: train loss 2.6216, val loss 2.8625
# step 7430: train loss 2.6202, val loss 2.6907
# step 7440: train loss 2.6270, val loss 2.6995
# step 7450: train loss 2.5905, val loss 2.6975
# step 7460: train loss 2.6128, val loss 2.6528
# step 7470: train loss 2.5129, val loss 2.6996
# step 7480: train loss 2.6232, val loss 2.5921
# step 7490: train loss 2.6324, val loss 2.6886
# step 7500: train loss 2.6134, val loss 2.6508
# step 7510: train loss 2.5761, val loss 2.7345
# step 7520: train loss 2.5650, val loss 2.7126
# step 7530: train loss 2.5512, val loss 2.7284
# step 7540: train loss 2.6498, val loss 2.7245
# step 7550: train loss 2.6351, val loss 2.6401
# step 7560: train loss 2.5415, val loss 2.6558
# step 7570: train loss 2.6588, val loss 2.6652
# step 7580: train loss 2.5261, val loss 2.7070
# step 7590: train loss 2.5507, val loss 2.6944
# step 7600: train loss 2.6027, val loss 2.7123
# step 7610: train loss 2.7149, val loss 2.6849
# step 7620: train loss 2.6995, val loss 2.6000
# step 7630: train loss 2.6074, val loss 2.7336
# step 7640: train loss 2.5512, val loss 2.6682
# step 7650: train loss 2.5594, val loss 2.7231
# step 7660: train loss 2.6313, val loss 2.5800
# step 7670: train loss 2.6662, val loss 2.6341
# step 7680: train loss 2.6204, val loss 2.6884
# step 7690: train loss 2.5587, val loss 2.5585
# step 7700: train loss 2.5747, val loss 2.6372
# step 7710: train loss 2.6368, val loss 2.6392
# step 7720: train loss 2.6041, val loss 2.6882
# step 7730: train loss 2.6491, val loss 2.6319
# step 7740: train loss 2.5475, val loss 2.6169
# step 7750: train loss 2.6282, val loss 2.6460
# step 7760: train loss 2.5298, val loss 2.7444
# step 7770: train loss 2.6433, val loss 2.7488
# step 7780: train loss 2.5231, val loss 2.7580
# step 7790: train loss 2.5784, val loss 2.7356
# step 7800: train loss 2.5122, val loss 2.6440
# step 7810: train loss 2.5230, val loss 2.6574
# step 7820: train loss 2.5833, val loss 2.6844
# step 7830: train loss 2.6009, val loss 2.7705
# step 7840: train loss 2.6952, val loss 2.6559
# step 7850: train loss 2.6501, val loss 2.7922
# step 7860: train loss 2.5759, val loss 2.6481
# step 7870: train loss 2.5030, val loss 2.7112
# step 7880: train loss 2.5443, val loss 2.5774
# step 7890: train loss 2.6249, val loss 2.6128
# step 7900: train loss 2.5766, val loss 2.5990
# step 7910: train loss 2.5262, val loss 2.5357
# step 7920: train loss 2.5146, val loss 2.5479
# step 7930: train loss 2.5949, val loss 2.6663
# step 7940: train loss 2.5441, val loss 2.6639
# step 7950: train loss 2.5401, val loss 2.7058
# step 7960: train loss 2.5999, val loss 2.6715
# step 7970: train loss 2.5588, val loss 2.6403
# step 7980: train loss 2.5981, val loss 2.6636
# step 7990: train loss 2.5442, val loss 2.6154
# step 8000: train loss 2.5871, val loss 2.6077
# step 8010: train loss 2.4943, val loss 2.6367
# step 8020: train loss 2.5763, val loss 2.5812
# step 8030: train loss 2.5354, val loss 2.5850
# step 8040: train loss 2.5747, val loss 2.5807
# step 8050: train loss 2.5109, val loss 2.6635
# step 8060: train loss 2.5271, val loss 2.6727
# step 8070: train loss 2.4781, val loss 2.7215
# step 8080: train loss 2.5872, val loss 2.6887
# step 8090: train loss 2.5577, val loss 2.7126
# step 8100: train loss 2.5235, val loss 2.5668
# step 8110: train loss 2.5485, val loss 2.6079
# step 8120: train loss 2.5643, val loss 2.7559
# step 8130: train loss 2.5859, val loss 2.5936
# step 8140: train loss 2.5335, val loss 2.6208
# step 8150: train loss 2.5370, val loss 2.7595
# step 8160: train loss 2.5057, val loss 2.6527
# step 8170: train loss 2.5778, val loss 2.6119
# step 8180: train loss 2.6091, val loss 2.6359
# step 8190: train loss 2.6764, val loss 2.7798
# step 8200: train loss 2.5032, val loss 2.6457
# step 8210: train loss 2.5471, val loss 2.7284
# step 8220: train loss 2.6641, val loss 2.7416
# step 8230: train loss 2.6468, val loss 2.6165
# step 8240: train loss 2.5064, val loss 2.6701
# step 8250: train loss 2.6327, val loss 2.6464
# step 8260: train loss 2.5547, val loss 2.7750
# step 8270: train loss 2.5438, val loss 2.5909
# step 8280: train loss 2.5728, val loss 2.5953
# step 8290: train loss 2.4906, val loss 2.6467
# step 8300: train loss 2.5366, val loss 2.5887
# step 8310: train loss 2.6169, val loss 2.4614
# step 8320: train loss 2.5911, val loss 2.6855
# step 8330: train loss 2.5583, val loss 2.6096
# step 8340: train loss 2.4657, val loss 2.6322
# step 8350: train loss 2.5241, val loss 2.5651
# step 8360: train loss 2.5724, val loss 2.6086
# step 8370: train loss 2.5106, val loss 2.6028
# step 8380: train loss 2.5667, val loss 2.6152
# step 8390: train loss 2.6030, val loss 2.6609
# step 8400: train loss 2.5353, val loss 2.5981
# step 8410: train loss 2.5154, val loss 2.5151
# step 8420: train loss 2.5498, val loss 2.5376
# step 8430: train loss 2.4817, val loss 2.6784
# step 8440: train loss 2.5415, val loss 2.6530
# step 8450: train loss 2.5526, val loss 2.5248
# step 8460: train loss 2.5680, val loss 2.6524
# step 8470: train loss 2.5262, val loss 2.6945
# step 8480: train loss 2.6099, val loss 2.5484
# step 8490: train loss 2.5481, val loss 2.6017
# step 8500: train loss 2.5559, val loss 2.5874
# step 8510: train loss 2.5214, val loss 2.6529
# step 8520: train loss 2.5360, val loss 2.6695
# step 8530: train loss 2.5838, val loss 2.5933
# step 8540: train loss 2.5470, val loss 2.5425
# step 8550: train loss 2.5884, val loss 2.5904
# step 8560: train loss 2.5190, val loss 2.7163
# step 8570: train loss 2.6674, val loss 2.6998
# step 8580: train loss 2.5372, val loss 2.7610
# step 8590: train loss 2.4862, val loss 2.6772
# step 8600: train loss 2.5259, val loss 2.5899
# step 8610: train loss 2.5038, val loss 2.5402
# step 8620: train loss 2.5327, val loss 2.6854
# step 8630: train loss 2.5081, val loss 2.7227
# step 8640: train loss 2.6547, val loss 2.7161
# step 8650: train loss 2.5266, val loss 2.5585
# step 8660: train loss 2.5444, val loss 2.6859
# step 8670: train loss 2.5748, val loss 2.6264
# step 8680: train loss 2.4696, val loss 2.6438
# step 8690: train loss 2.6294, val loss 2.5985
# step 8700: train loss 2.4925, val loss 2.5962
# step 8710: train loss 2.5681, val loss 2.5848
# step 8720: train loss 2.5746, val loss 2.7031
# step 8730: train loss 2.5746, val loss 2.7287
# step 8740: train loss 2.4672, val loss 2.6516
# step 8750: train loss 2.5734, val loss 2.6538
# step 8760: train loss 2.4963, val loss 2.5388
# step 8770: train loss 2.5071, val loss 2.6567
# step 8780: train loss 2.5695, val loss 2.5886
# step 8790: train loss 2.5638, val loss 2.6505
# step 8800: train loss 2.5039, val loss 2.6322
# step 8810: train loss 2.5176, val loss 2.6179
# step 8820: train loss 2.4740, val loss 2.5732
# step 8830: train loss 2.5568, val loss 2.6292
# step 8840: train loss 2.5899, val loss 2.6043
# step 8850: train loss 2.5779, val loss 2.5087
# step 8860: train loss 2.5587, val loss 2.5794
# step 8870: train loss 2.5241, val loss 2.5291
# step 8880: train loss 2.6049, val loss 2.5744
# step 8890: train loss 2.5550, val loss 2.7220
# step 8900: train loss 2.5069, val loss 2.6285
# step 8910: train loss 2.4861, val loss 2.6082
# step 8920: train loss 2.5016, val loss 2.5472
# step 8930: train loss 2.5037, val loss 2.5448
# step 8940: train loss 2.4769, val loss 2.7004
# step 8950: train loss 2.5079, val loss 2.5623
# step 8960: train loss 2.4261, val loss 2.6047
# step 8970: train loss 2.5355, val loss 2.5870
# step 8980: train loss 2.5207, val loss 2.5623
# step 8990: train loss 2.6255, val loss 2.5597
# step 9000: train loss 2.4754, val loss 2.5622
# step 9010: train loss 2.4815, val loss 2.6543
# step 9020: train loss 2.4409, val loss 2.6652
# step 9030: train loss 2.5215, val loss 2.6151
# step 9040: train loss 2.5207, val loss 2.5600
# step 9050: train loss 2.5525, val loss 2.4549
# step 9060: train loss 2.5486, val loss 2.5452
# step 9070: train loss 2.4943, val loss 2.5723
# step 9080: train loss 2.5741, val loss 2.5823
# step 9090: train loss 2.6349, val loss 2.5916
# step 9100: train loss 2.6609, val loss 2.6485
# step 9110: train loss 2.5511, val loss 2.5393
# step 9120: train loss 2.5862, val loss 2.6093
# step 9130: train loss 2.5628, val loss 2.5644
# step 9140: train loss 2.5006, val loss 2.6416
# step 9150: train loss 2.5738, val loss 2.5432
# step 9160: train loss 2.4873, val loss 2.5445
# step 9170: train loss 2.5777, val loss 2.6364
# step 9180: train loss 2.4598, val loss 2.6062
# step 9190: train loss 2.4630, val loss 2.6103
# step 9200: train loss 2.4996, val loss 2.5354
# step 9210: train loss 2.5704, val loss 2.6499
# step 9220: train loss 2.5447, val loss 2.6717
# step 9230: train loss 2.4976, val loss 2.6366
# step 9240: train loss 2.4845, val loss 2.6583
# step 9250: train loss 2.5405, val loss 2.6121
# step 9260: train loss 2.5507, val loss 2.6232
# step 9270: train loss 2.5267, val loss 2.6851
# step 9280: train loss 2.5375, val loss 2.6066
# step 9290: train loss 2.5082, val loss 2.4994
# step 9300: train loss 2.4722, val loss 2.5838
# step 9310: train loss 2.5376, val loss 2.6263
# step 9320: train loss 2.5088, val loss 2.5831
# step 9330: train loss 2.3912, val loss 2.5545
# step 9340: train loss 2.5309, val loss 2.5536
# step 9350: train loss 2.4741, val loss 2.6756
# step 9360: train loss 2.5840, val loss 2.7265
# step 9370: train loss 2.5411, val loss 2.6161
# step 9380: train loss 2.5155, val loss 2.5895
# step 9390: train loss 2.4144, val loss 2.5868
# step 9400: train loss 2.5366, val loss 2.6261
# step 9410: train loss 2.4607, val loss 2.6167
# step 9420: train loss 2.5216, val loss 2.5682
# step 9430: train loss 2.5158, val loss 2.6781
# step 9440: train loss 2.5379, val loss 2.5454
# step 9450: train loss 2.4929, val loss 2.5883
# step 9460: train loss 2.4970, val loss 2.6557
# step 9470: train loss 2.4671, val loss 2.5701
# step 9480: train loss 2.4901, val loss 2.7378
# step 9490: train loss 2.4632, val loss 2.6750
# step 9500: train loss 2.5307, val loss 2.6933
# step 9510: train loss 2.4771, val loss 2.5288
# step 9520: train loss 2.4923, val loss 2.6699
# step 9530: train loss 2.4775, val loss 2.4688
# step 9540: train loss 2.5181, val loss 2.7079
# step 9550: train loss 2.5242, val loss 2.5604
# step 9560: train loss 2.6139, val loss 2.5163
# step 9570: train loss 2.4245, val loss 2.5944
# step 9580: train loss 2.4942, val loss 2.5160
# step 9590: train loss 2.4634, val loss 2.7495
# step 9600: train loss 2.5603, val loss 2.7553
# step 9610: train loss 2.4321, val loss 2.5170
# step 9620: train loss 2.4864, val loss 2.6428
# step 9630: train loss 2.5002, val loss 2.5361
# step 9640: train loss 2.5106, val loss 2.6393
# step 9650: train loss 2.5555, val loss 2.7232
# step 9660: train loss 2.5304, val loss 2.4728
# step 9670: train loss 2.4688, val loss 2.6217
# step 9680: train loss 2.4894, val loss 2.5832
# step 9690: train loss 2.4042, val loss 2.4712
# step 9700: train loss 2.5995, val loss 2.5833
# step 9710: train loss 2.5376, val loss 2.6398
# step 9720: train loss 2.5403, val loss 2.6496
# step 9730: train loss 2.5358, val loss 2.5345
# step 9740: train loss 2.4181, val loss 2.6119
# step 9750: train loss 2.5222, val loss 2.6072
# step 9760: train loss 2.4216, val loss 2.5152
# step 9770: train loss 2.4802, val loss 2.6089
# step 9780: train loss 2.4977, val loss 2.6869
# step 9790: train loss 2.4760, val loss 2.6347
# step 9800: train loss 2.4447, val loss 2.6051
# step 9810: train loss 2.4442, val loss 2.6166
# step 9820: train loss 2.4083, val loss 2.6630
# step 9830: train loss 2.5205, val loss 2.6025
# step 9840: train loss 2.4891, val loss 2.6663
# step 9850: train loss 2.4900, val loss 2.4937
# step 9860: train loss 2.5023, val loss 2.6193
# step 9870: train loss 2.4577, val loss 2.5141
# step 9880: train loss 2.4398, val loss 2.5334
# step 9890: train loss 2.4923, val loss 2.6611
# step 9900: train loss 2.4302, val loss 2.6981
# step 9910: train loss 2.4903, val loss 2.5447
# step 9920: train loss 2.5407, val loss 2.6055
# step 9930: train loss 2.5758, val loss 2.5449
# step 9940: train loss 2.4629, val loss 2.6231
# step 9950: train loss 2.5055, val loss 2.5959
# step 9960: train loss 2.5316, val loss 2.4845
# step 9970: train loss 2.5280, val loss 2.7191
# step 9980: train loss 2.4773, val loss 2.5322
# step 9990: train loss 2.5354, val loss 2.5901

# %% [markdown]
# Once the network has been trained for 100 iterations, we can generate a sequence of characters.
#
# #### Questions:
# - What is the effect of training?
# - Increase the number of iterations to 1,000 and then to 10,000. Note the obtained loss and the generated sentence. What do you observe?

# %%
# Create a prompt as a tensor of size (1,1) containing the integer corresponding to the character '\n'
prompt = torch.tensor([[stoi['\n']]], dtype=torch.long).to(device)

# Generate a sequence of 100 characters from this prompt
generated_sequence = m.generate(prompt, max_new_tokens=100)

# Decode the generated sequence to get the string
generated_text = decode(generated_sequence[0].tolist())

print(generated_text)
# Out:
# OR
# HÊ74à h.
# JkD'i vou qu
# Sex!f,
# L'erdrt c lxCù uraurr.
# Sit8de e 16Fos domacebe es hèr?M42Brs  heme,

# %% [markdown]
# after training with 1000 , a see that the model still givin completely non sense sentences , but at least he learns how to move to another line, but with 10000 the model still giving non sense sentences but in a more organized way

# %% [markdown]
# ## Single Head Attention
#
# We will now implement the basic attention mechanism. For each pair of words in the sequence, this mechanism combines:
# - **Q** (*query*): the information being searched for,
# - **K** (*key*): the information retrieved,
# - **V** (*value*): a result vector calculated from the attention mechanism.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masking
#
# However, since we are using the model to generate sequences, we must not use characters that come after the current character—these are precisely the characters we aim to predict during training. *The future should not be used to predict the future.*
#
# To enforce this constraint, we integrate a **masking matrix** into the process. This matrix ensures that:
# - For the first character in the sequence, only that character is available for prediction (no context).
# - For the second character, only the first and second characters can be used.
# - For the third character, only the first three characters are accessible, and so on.
#
# This results in a **lower triangular matrix**, where each row is normalized (rows sum to 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# The [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) function provides another way to achieve normalization.
#
# #### Question:
# - Verify that applying `softmax` results in the same lower triangular matrix.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implementation
#
# We can now implement the attention layer based on the following formula:
#
# ![attention_formula](images/attention_formula.png)
#
# This involves computing the **queries (Q)**, **keys (K)**, and **values (V)**, applying the **masking mechanism**, and using the **softmax function** to normalize the attention scores before computing the weighted sum of values.

# %% [markdown]
# #### Questions:
#
# - Create the **key**, **query**, and **value** layers as linear layers of dimension `C × head_size`.
# - Apply these layers to `x`.
# - Compute the attention weights:
#   ```python
#   weights = query @ key.transpose(-2, -1)
#   ```
#   (Transpose the second and third dimensions of `key` to enable matrix multiplication).
# - Apply the **normalization factor** (typically, divide by `sqrt(head_size)`).
# - Apply the **triangular mask** and the **softmax** function to `weights`.
# - Apply the **value** layer to `x`.
# - Compute the final output:
#   ```python
#   out = weights @ value(x)
#   ```

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)

# define the Key layer  
key = nn.Linear(C, head_size, bias=False)
# define the Query layer
query = nn.Linear(C, head_size, bias=False)
# define the Value layer
value = nn.Linear(C, head_size, bias=False)

# apply each layer to the input
k = key(x)  # (B, T, head_size)
q = query(x)  # (B, T, head_size)
v = value(x)  # (B, T, head_size)

# compute the normalized product between Q and K 
weights = q @ k.transpose(-2, -1) / head_size**0.5  # (B, T, head_size) @ (B, head_size, T) -> (B, T, T)

# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril == 0, float('-inf'))

# apply the softmax
weights = nn.functional.softmax(weights, dim=-1)

out = weights @ v  # (B, T, T) @ (B, T, head_size) -> (B, T, head_size)

# print the result
print(weights[0])
print(out[0])
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3842, 0.6158, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.4458, 0.3427, 0.2115, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3025, 0.2059, 0.2573, 0.2343, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2097, 0.2211, 0.2128, 0.1709, 0.1855, 0.0000, 0.0000, 0.0000],
#         [0.2752, 0.1196, 0.1132, 0.1426, 0.0948, 0.2545, 0.0000, 0.0000],
#         [0.2064, 0.1505, 0.1752, 0.1306, 0.1061, 0.1443, 0.0870, 0.0000],
#         [0.0766, 0.1019, 0.1084, 0.0832, 0.4182, 0.0611, 0.0465, 0.1041]],
#        grad_fn=<SelectBackward0>)
# tensor([[-5.4369e-01, -1.0828e+00,  1.4988e+00, -2.4032e-01,  1.1141e-01,
#          -2.1976e-01, -3.5047e-01,  3.6540e-01, -3.6055e-01, -2.7056e-01,
#           1.2711e+00,  5.7167e-01,  5.3217e-01,  1.3346e-02,  7.5330e-01,
#           6.0703e-01],
#         [ 4.0222e-01, -3.3792e-01,  1.1559e+00, -1.7454e-01, -2.5728e-01,
#           3.6617e-02, -3.7717e-01,  3.0202e-01, -4.2233e-01,  6.2505e-01,
#           5.6948e-01, -2.9201e-01,  5.4542e-02,  2.8612e-02,  4.1105e-01,
#           6.2225e-01],
#         [ 1.7370e-02, -4.1771e-01,  1.0528e+00, -3.7312e-02, -8.0902e-02,
#          -1.5212e-01, -3.0841e-01, -2.2080e-02, -3.8589e-01,  3.0198e-01,
#           5.5552e-01,  1.1906e-01,  7.2742e-02, -8.2621e-02,  3.7531e-01,
#           3.6916e-01],
#         [-1.7584e-01, -3.1683e-01,  5.7584e-01, -3.0641e-02,  2.2021e-01,
#          -2.8355e-01, -2.8602e-01, -1.1016e-01, -4.1349e-01,  3.0683e-02,
#           6.1487e-01,  1.8149e-01, -1.1025e-01, -1.8560e-02,  9.9860e-03,
#          -7.1706e-03],
#         [ 6.8262e-02, -3.2357e-01,  5.6194e-01,  3.3808e-02, -6.9462e-02,
#          -1.7519e-01, -1.0823e-01, -1.7487e-01, -3.1935e-01,  2.8581e-01,
#           3.2667e-01,  2.0226e-01, -1.3838e-01,  1.4339e-01, -5.8910e-02,
#          -5.4938e-02],
#         [-2.0732e-01, -5.5680e-01,  7.4579e-01, -1.0174e-01,  3.7409e-03,
#          -2.4597e-01, -1.9219e-02,  6.6108e-04, -3.1072e-01,  1.2136e-02,
#           5.7302e-01,  3.0500e-01,  2.7521e-01,  1.6917e-01, -4.4496e-02,
#           2.6725e-02],
#         [-1.0833e-01, -4.3955e-01,  5.0485e-01, -3.8240e-02, -2.7159e-02,
#          -2.0850e-01, -3.3895e-02, -1.4505e-01, -3.5249e-01,  5.8703e-02,
#           3.9697e-01,  3.0418e-01,  8.1831e-02,  9.9883e-02, -9.0683e-02,
#          -1.4382e-01],
#         [ 1.2167e-01, -4.4812e-01,  3.2287e-01,  1.0893e-01, -3.3499e-01,
#          -4.6079e-02, -1.4036e-02, -1.8359e-01, -1.0045e-01,  4.1889e-01,
#          -9.0037e-03,  3.8845e-01, -1.3184e-01,  2.4837e-01, -2.1723e-01,
#          -1.8728e-01]], grad_fn=<SelectBackward0>)

# %% [markdown]
# ### Questions:
#
# - Copy your code into `gpt_single_head.py`:
#   - Define the **key**, **query**, and **value** layers in the **constructor** of the `Head` class.
#   - Implement the **computations** in the `forward` function.
# - Train the model.
# - What are the **training** and **validation** losses?
# - Does the generated text appear **better** compared to the previous model?

# %% [markdown]
# ## Multi-Head Attention
#
# Multi-head attention is simply the parallel computation of multiple **single-head attention** mechanisms. Each **single-head attention** output is concatenated to form the output of the **multi-head attention** module. In the original paper's illustration, the number of heads in the **multi-head attention** is denoted as `h`.
#
# To allow for **weighted combinations** of each single-head attention output, a **linear transformation layer** is added after concatenation.
#
# ![multi head attention](images/multi_head_attention.png)
#
# #### Questions:
#
# - In the **constructor**, create a list containing `num_heads` instances of the `Head` module using PyTorch’s [`ModuleList`](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html).
# - In the `forward` function:
#   - Apply each **single-head attention** to the input.
#   - Concatenate the results using PyTorch’s [`cat`](https://pytorch.org/docs/stable/generated/torch.cat.html) function.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# #### Questions:
#
# 1. **Copy** the file `gpt_single_head.py` and rename it as `gpt_multi_head.py`.
# 2. **Add** the `MultiHeadAttention` module in `gpt_multi_head.py`.
# 3. At the **beginning of the file**, add a parameter:
#    ```python
#    n_head = 4
#    ```
# 4. In the `BigramLanguageModel` module, **replace** the `Head` module with `MultiHeadAttention`, using the parameters:
#    ```python
#    num_heads = n_head
#    head_size = n_embd // n_head
#    ```
#    This ensures the total number of parameters remains **the same**.
# 5. **Retrain the model** and note:
#    - The total number of **parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802
# ```

# %% [markdown]
# ## Adding a FeedForward Computation Layer
#
# After the **attention layers**, which collect information from the sequence, a **computation layer** is added to combine all the gathered information.
#
# This layer is a simple **Multi-Layer Perceptron (MLP)** with:
# - One **hidden layer**,
# - A **ReLU non-linearity** using [`ReLU`](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
#
# ### Architecture:
#
# <img src="images/multi_ff.png" alt="multi feedforward" width="200">

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# #### Questions:
#
# 1. **Add** the `FeedForward` module to your `gpt_multi_head.py` file.
# 2. **Integrate** this `FeedForward` layer **after** the **multi-head attention** module.
# 3. **Retrain the model** and note:
#    - The total **number of parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216
# ```

# %% [markdown]
# ## Stacking Blocks
#
# The network we have built so far represents just **one block** of the final model. Now, we can **stack multiple blocks** of **multi-head attention** to create a **deeper** network.
#
# ### Architecture:
# ![multi feedforward](images/multi_bloc.png)
#
# The following code defines a **block**:

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# #### Questions:
#
# - Add the `Block` module to `gpt_multi_head.py`.
# - Modify the `BigramLanguageModel` code to include **three** instances of `Block(n_embd, n_head=4)`, using a [`Sequential`](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) container **instead of** `MultiHeadAttention` and `FeedForward`.
# - Retrain the model and note:
#   - The **number of parameters**
#   - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213
# ```

# %% [markdown]
# ## Improving Training
#
# If we want to continue increasing the **network size**, we need to incorporate layers that **enhance training stability** and **improve generalization** (reducing overfitting). These layers include:
#
# - **Skip connections** (or **residual connections**)
# - **Normalization layers**
# - **Dropout**
#
# ### Updated Architecture:
#
# <img src="images/multi_skip_norm.png" alt="multi feedforward" width="200">
#
# ---
#
# #### Questions:
#
# 1. In the `Block` module, **add a skip connection** by summing the input at each step:
#    ```python
#    x = x + self.sa(self.ln1(x))
#    x = x + self.ffwd(self.ln2(x))
#    ```
#
# 2. In the `Block` module, **add two** [`LayerNorm`](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) layers of size `n_embd`:
#    - **Before** the `Multi-Head Attention` layer.
#    - **Before** the `FeedForward` layer.
#
# 3. **After the sequence of 3 blocks**, add a **LayerNorm** layer of size `n_embd`.
#
# 4. Define a variable at the **beginning of the file**:
#    ```python
#    dropout = 0.2
#    ```
#    Then add a [`Dropout`](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) layer:
#    - **After** the `ReLU` activation in `FeedForward`.
#    - **After** the `Multi-Head Attention` layer in `MultiHeadAttention`.
#    - **After** the `softmax` layer in the single-head attention `Head`.
#
# 5. **Retrain the model** and note:
#    - The **number of parameters**
#    - The **training** and **validation** losses
#
# ---
#
# **Expected Output Example:**
# ```
# 0.019653 M parameters
# ```

# %% [markdown]
# ## Conclusion
#
# The key components of **GPT-2** are now in place. The next step is to **scale up** the model and train it on a **much larger** dataset. For comparison, the parameters of [GPT-2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) are:
#
# - **`vocab_size = 50257`** → GPT-2 models **subword tokens**, while we model **characters**. For us, `vocab_size = 100`.
# - **`n_positions = 1024`** → The maximum **context size**. For us, it's `block_size = 8`.
# - **`n_embd = 768`** → The **embedding dimension**. For us, it's `n_embd = 32`.
# - **`n_layer = 12`** → The number of **blocks**. For us, it's `3`.
# - **`n_head = 12`** → The number of **multi-head attention layers**. For us, it's `4`.
#
# Overall, **GPT-2** consists of **1.5 billion parameters** and was trained on **8 million web pages**, totaling **40 GB of text**.
#
# ---
#
# ### **Training Results**
# ```text
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
# ```
#
# ### **Generated Text Sample:**
#
# ```text
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
