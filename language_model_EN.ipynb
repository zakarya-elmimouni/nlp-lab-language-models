# %% [markdown]
# # NLP Lab: Language Models
#
# In this lab, we will build the main components of the GPT-2 model and train a small model on poems by Victor Hugo.
#
# The questions are included in this notebook. To run the training, you will need to modify the `gpt_single_head.py` file, which is also available in the Git repository.
#
# ## Data
#
# The training data consists of a collection of poems by Victor Hugo, sourced from [gutenberg.org](https://www.gutenberg.org/). The dataset is available in the `data` directory.
#
# To reduce model complexity, we will model the text at the character level. Typically, language models process sequences of subwords using [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) such as BPE, SentencePiece, or WordPiece.
#
# #### Questions:
# - Using [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), display the number of unique characters in the text and the frequency of each character.

# %%
import collections
from collections import Counter

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE

###

counter = Counter(text)
chars = sorted(counter.keys())

print(f'Number of character in counter: {sum(counter.values())}')
print(f'{len(chars)} different characters')
print(counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encoding / Decoding
#
# To transform the text into a vector for the neural network, each character must be encoded as an integer.
#
# The following functions perform the encoding and decoding of characters:

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Train/Validation Split
#
# Since the goal is to predict poems, the lines should not be shuffled randomly. Instead, we must preserve the order of the lines in the text and take only the first 90% for training, while using the remaining 10% to monitor learning.
#
# #### Questions:
# - Split the data into `train_data` (90%) and `val_data` (10%) using slicing on the dataset.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
# first 90% will be train, rest val
split_idx = int(0.9 * len(data))

# Split the data
train_data = data[:split_idx]
val_data = data[split_idx:]

print(f'Train data length: {len(train_data)}')
print(f'Validation data length: {len(val_data)}')
###
# Out:
# Train data length: 256699
# Validation data length: 28523

# %% [markdown]
# ### Context
#
# The language model has a parameter that defines the maximum context size to consider when predicting the next character. This context is called `block_size`. The training data consists of sequences of consecutive characters, randomly sampled from the training set, with a length of `block_size`.
#
# If the starting character of the sequence is `i`, then the context sequence is:
# ```python
# x = data[i:i+block_size]
# ```
# And the target value to predict at each position in the context is the next character:
# ```python
# y = data[i+1:i+block_size+1]
# ```

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([24066])
# context is > < target is > <
# context is >  < target is > <
# context is >   < target is > <
# context is >    < target is > <
# context is >     < target is > <
# context is >      < target is > <
# context is >       < target is > <
# context is >        < target is >F<

# %% [markdown]
# ### Defining Batches
#
# The training batches consist of multiple character sequences randomly sampled from `train_data`. To randomly select a sequence for the batch, we need to randomly pick a starting point in `train_data` and extract the following `block_size` characters. When selecting the starting point, ensure that there are enough characters remaining after it to form a full sequence of `block_size` characters.
#
# #### Questions:
# - Create the batches `x` by selecting `batch_size` sequences of length `block_size` starting from a randomly chosen index `i`. Stack the examples using `torch.stack`.
# - Create the batches `y` by adding the next character following each sequence in `x`. Stack the examples using `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    starting_points = torch.randint(len(data) - block_size, (batch_size,))
    
    x = torch.stack([data[i:i+block_size] for i in starting_points])
    y = torch.stack([data[i+1:i+block_size+1] for i in starting_points])
    
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y
# Out:
# Using device: cuda

# %% [markdown]
# ### First Model: A Bigram Model
#
# The first model we will implement is a bigram model. It predicts the next character based only on the current character. This model can be stored in a simple matrix: for each character (row), we store the probability distribution over all possible next characters (columns). This can be implemented using a simple [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html) layer in PyTorch.
#
# #### Questions:
# - In the constructor, define an Embedding layer of size `vocab_size × vocab_size`.
# - In the `forward` method, apply the embedding layer to the batch of indices (`x`).
# - In the `forward` method, define the loss as `cross_entropy` between the predictions and the target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)

        ## 
        
    def forward(self, idx, targets=None):
        # idx and targets are both (Batch, Time) tensor of integers
        logits = self.token_embedding_table(idx)  # (Batch, Time, Channel)
        
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch * Time, Channels)
            targets = targets.view(Batch * Time)
            
            # negative log likelihood between prediction and target
            loss = nn.functional.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx
vocab_size=101
model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# ### Model Before Training
#
# At this stage, the model has not yet been trained—it has only been initialized. However, we can already compute the loss on a random batch. Since the weights are initialized with a normal distribution \( N(0,1) \) for each dimension, the expected loss after initialization should be close to `-ln(1/vocab_size)`, as the entropy is maximal.

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'Expected loss {-math.log(1.0/vocab_size)}')
print (f'Computed loss {loss}')
# Out:
# torch.Size([32, 101])
# Expected loss 4.61512051684126
# Computed loss 4.9072675704956055

# %% [markdown]
# ### Using the Model for Prediction
#
# To use the model for prediction, we need to provide an initial character to start the sequence—this is called the prompt. In our case, we can initialize the generation with the newline character (`\n`) to start a new sentence.
#
# #### Questions:
# - Create a prompt as a tensor of size `(1,1)` containing the integer corresponding to the character `\n`.
# - Generate a sequence of 100 characters from this prompt using the functions `m.generate` and `decode`.
# - How does the generated sentence look?

# %%
# Create a prompt as a tensor of size (1,1) containing the integer corresponding to the character '\n'
prompt = torch.tensor([[stoi['\n']]], dtype=torch.long).to(device)

# Generate a sequence of 100 characters from this prompt
generated_sequence = m.generate(prompt, max_new_tokens=100)

# Decode the generated sequence to get the string
generated_text = decode(generated_sequence[0].tolist())

print(generated_text)
# Out:
# aG:I
# aéPwÉEl!è2YpÎpKIuU.ôZUwZ_Èt«bN_;c.8(hO1ÀÀhZVèÂmeôW!5«8XRTkRB·3?KÔ)[lmSËûÈ9àxIJxIêScfî-EPuaFR2ÊÆ

# %% [markdown]
# completly non sense sentence!

# %% [markdown]
# ### Training
#
# For training, we use the [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) optimizer with a learning rate of `1e-3`. Each training iteration consists of the following steps:
#
# - Generate a batch
# - Apply the neural network (forward pass) and compute the loss: `model(xb, yb)`
# - Compute the gradient (after resetting accumulated gradients): `loss.backward()`
# - Update the parameters: `optimizer.step()`

# %%
max_iters = 10000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.0941, val loss 5.1389
# step 10: train loss 5.1514, val loss 5.0392
# step 20: train loss 5.1237, val loss 5.1288
# step 30: train loss 5.1393, val loss 5.0619
# step 40: train loss 5.1591, val loss 5.1039
# step 50: train loss 5.1344, val loss 5.0613
# step 60: train loss 5.0400, val loss 5.0135
# step 70: train loss 5.1054, val loss 4.9915
# step 80: train loss 5.0899, val loss 5.0301
# step 90: train loss 4.9490, val loss 4.9858
# step 100: train loss 5.0638, val loss 4.9649
# step 110: train loss 5.0442, val loss 5.0224
# step 120: train loss 5.0176, val loss 4.9676
# step 130: train loss 4.9808, val loss 4.9644
# step 140: train loss 5.0095, val loss 4.9948
# step 150: train loss 5.0607, val loss 4.9927
# step 160: train loss 5.0148, val loss 5.0460
# step 170: train loss 4.9509, val loss 5.0320
# step 180: train loss 5.0122, val loss 4.9658
# step 190: train loss 4.9532, val loss 4.8777
# step 200: train loss 4.9358, val loss 4.8695
# step 210: train loss 4.9521, val loss 4.9503
# step 220: train loss 4.9577, val loss 4.9298
# step 230: train loss 4.8986, val loss 4.8962
# step 240: train loss 4.9419, val loss 4.8879
# step 250: train loss 4.9554, val loss 4.8138
# step 260: train loss 4.8639, val loss 4.8166
# step 270: train loss 4.8932, val loss 4.8480
# step 280: train loss 4.9107, val loss 4.7795
# step 290: train loss 4.8940, val loss 4.8777
# step 300: train loss 4.8773, val loss 4.7579
# step 310: train loss 4.8793, val loss 4.9003
# step 320: train loss 4.8545, val loss 4.8020
# step 330: train loss 4.8127, val loss 4.8168
# step 340: train loss 4.8075, val loss 4.7653
# step 350: train loss 4.8316, val loss 4.7839
# step 360: train loss 4.8241, val loss 4.7854
# step 370: train loss 4.8161, val loss 4.7468
# step 380: train loss 4.7888, val loss 4.7630
# step 390: train loss 4.8550, val loss 4.7464
# step 400: train loss 4.7879, val loss 4.8240
# step 410: train loss 4.7468, val loss 4.8512
# step 420: train loss 4.8253, val loss 4.7592
# step 430: train loss 4.7395, val loss 4.7978
# step 440: train loss 4.8534, val loss 4.7503
# step 450: train loss 4.7837, val loss 4.6671
# step 460: train loss 4.7879, val loss 4.6938
# step 470: train loss 4.8103, val loss 4.7191
# step 480: train loss 4.7299, val loss 4.6617
# step 490: train loss 4.6949, val loss 4.7029
# step 500: train loss 4.7691, val loss 4.6451
# step 510: train loss 4.7761, val loss 4.6392
# step 520: train loss 4.6937, val loss 4.6765
# step 530: train loss 4.7067, val loss 4.6676
# step 540: train loss 4.6940, val loss 4.6007
# step 550: train loss 4.6405, val loss 4.7378
# step 560: train loss 4.7177, val loss 4.5838
# step 570: train loss 4.6425, val loss 4.6289
# step 580: train loss 4.6438, val loss 4.6226
# step 590: train loss 4.7030, val loss 4.5584
# step 600: train loss 4.7122, val loss 4.6175
# step 610: train loss 4.6330, val loss 4.5842
# step 620: train loss 4.6578, val loss 4.6112
# step 630: train loss 4.6239, val loss 4.5196
# step 640: train loss 4.5766, val loss 4.5034
# step 650: train loss 4.5655, val loss 4.5172
# step 660: train loss 4.6027, val loss 4.5953
# step 670: train loss 4.5900, val loss 4.5091
# step 680: train loss 4.5913, val loss 4.5298
# step 690: train loss 4.5971, val loss 4.5425
# step 700: train loss 4.5276, val loss 4.5661
# step 710: train loss 4.5540, val loss 4.5598
# step 720: train loss 4.5721, val loss 4.5202
# step 730: train loss 4.5152, val loss 4.4584
# step 740: train loss 4.5420, val loss 4.5025
# step 750: train loss 4.5226, val loss 4.4612
# step 760: train loss 4.4820, val loss 4.5476
# step 770: train loss 4.5344, val loss 4.4596
# step 780: train loss 4.4747, val loss 4.4314
# step 790: train loss 4.5267, val loss 4.4795
# step 800: train loss 4.5178, val loss 4.5273
# step 810: train loss 4.4487, val loss 4.4765
# step 820: train loss 4.4037, val loss 4.4480
# step 830: train loss 4.4553, val loss 4.4416
# step 840: train loss 4.4538, val loss 4.4572
# step 850: train loss 4.3982, val loss 4.4363
# step 860: train loss 4.3726, val loss 4.4229
# step 870: train loss 4.4403, val loss 4.3982
# step 880: train loss 4.3803, val loss 4.3843
# step 890: train loss 4.4056, val loss 4.4090
# step 900: train loss 4.4496, val loss 4.4124
# step 910: train loss 4.3544, val loss 4.3008
# step 920: train loss 4.3869, val loss 4.2837
# step 930: train loss 4.4671, val loss 4.3528
# step 940: train loss 4.3288, val loss 4.3828
# step 950: train loss 4.3814, val loss 4.3337
# step 960: train loss 4.3863, val loss 4.3867
# step 970: train loss 4.4140, val loss 4.2698
# step 980: train loss 4.3895, val loss 4.2848
# step 990: train loss 4.3139, val loss 4.3668
# step 1000: train loss 4.3937, val loss 4.3029
# step 1010: train loss 4.3687, val loss 4.2616
# step 1020: train loss 4.3123, val loss 4.2575
# step 1030: train loss 4.3644, val loss 4.1794
# step 1040: train loss 4.2682, val loss 4.2152
# step 1050: train loss 4.2977, val loss 4.2313
# step 1060: train loss 4.2712, val loss 4.2464
# step 1070: train loss 4.3898, val loss 4.2415
# step 1080: train loss 4.2310, val loss 4.2651
# step 1090: train loss 4.2145, val loss 4.2519
# step 1100: train loss 4.3400, val loss 4.2873
# step 1110: train loss 4.2609, val loss 4.1544
# step 1120: train loss 4.2127, val loss 4.3099
# step 1130: train loss 4.2123, val loss 4.1276
# step 1140: train loss 4.3197, val loss 4.2178
# step 1150: train loss 4.2104, val loss 4.2883
# step 1160: train loss 4.2519, val loss 4.2281
# step 1170: train loss 4.1564, val loss 4.2040
# step 1180: train loss 4.2488, val loss 4.1789
# step 1190: train loss 4.2198, val loss 4.1276
# step 1200: train loss 4.1818, val loss 4.0901
# step 1210: train loss 4.2311, val loss 4.1513
# step 1220: train loss 4.2149, val loss 4.1653
# step 1230: train loss 4.1831, val loss 4.2215
# step 1240: train loss 4.2192, val loss 4.1566
# step 1250: train loss 4.1812, val loss 4.0973
# step 1260: train loss 4.1314, val loss 4.1354
# step 1270: train loss 4.1153, val loss 4.1728
# step 1280: train loss 4.1745, val loss 4.1463
# step 1290: train loss 4.1727, val loss 4.1273
# step 1300: train loss 4.1315, val loss 4.1127
# step 1310: train loss 4.1342, val loss 4.1028
# step 1320: train loss 4.0990, val loss 4.1075
# step 1330: train loss 4.0989, val loss 4.1258
# step 1340: train loss 4.0364, val loss 4.0468
# step 1350: train loss 4.1022, val loss 4.0874
# step 1360: train loss 4.0850, val loss 4.1817
# step 1370: train loss 4.1237, val loss 4.1491
# step 1380: train loss 4.0395, val loss 4.1231
# step 1390: train loss 4.0335, val loss 4.0608
# step 1400: train loss 4.0877, val loss 4.0911
# step 1410: train loss 4.0663, val loss 4.0708
# step 1420: train loss 4.0883, val loss 4.0586
# step 1430: train loss 4.0866, val loss 4.0276
# step 1440: train loss 4.0335, val loss 3.9836
# step 1450: train loss 4.0029, val loss 4.0759
# step 1460: train loss 3.9883, val loss 3.9781
# step 1470: train loss 4.0111, val loss 3.9552
# step 1480: train loss 4.0368, val loss 4.0652
# step 1490: train loss 3.9872, val loss 4.0228
# step 1500: train loss 4.0210, val loss 3.9753
# step 1510: train loss 4.0583, val loss 3.9877
# step 1520: train loss 3.9581, val loss 4.0433
# step 1530: train loss 4.0322, val loss 3.9360
# step 1540: train loss 3.9711, val loss 3.9700
# step 1550: train loss 4.0342, val loss 3.9733
# step 1560: train loss 3.9891, val loss 3.9880
# step 1570: train loss 3.9006, val loss 3.9818
# step 1580: train loss 3.9345, val loss 3.9061
# step 1590: train loss 3.9323, val loss 3.9709
# step 1600: train loss 3.9358, val loss 3.9422
# step 1610: train loss 3.9526, val loss 3.9588
# step 1620: train loss 3.9426, val loss 3.8828
# step 1630: train loss 3.8940, val loss 3.9666
# step 1640: train loss 3.9508, val loss 3.9440
# step 1650: train loss 3.9724, val loss 3.8363
# step 1660: train loss 3.9285, val loss 3.9127
# step 1670: train loss 3.9051, val loss 3.8995
# step 1680: train loss 3.9550, val loss 3.8768
# step 1690: train loss 3.8300, val loss 3.8897
# step 1700: train loss 3.9825, val loss 3.8255
# step 1710: train loss 3.8408, val loss 3.9261
# step 1720: train loss 3.8566, val loss 3.8091
# step 1730: train loss 3.8239, val loss 3.8875
# step 1740: train loss 3.8795, val loss 3.7563
# step 1750: train loss 3.8798, val loss 3.8066
# step 1760: train loss 3.8372, val loss 3.8364
# step 1770: train loss 3.8497, val loss 3.8168
# step 1780: train loss 3.8512, val loss 3.8963
# step 1790: train loss 3.8772, val loss 3.8682
# step 1800: train loss 3.8361, val loss 3.8740
# step 1810: train loss 3.7949, val loss 3.7904
# step 1820: train loss 3.8181, val loss 3.8651
# step 1830: train loss 3.8300, val loss 3.7750
# step 1840: train loss 3.7936, val loss 3.7500
# step 1850: train loss 3.8586, val loss 3.8956
# step 1860: train loss 3.8233, val loss 3.8099
# step 1870: train loss 3.7627, val loss 3.7372
# step 1880: train loss 3.8563, val loss 3.7142
# step 1890: train loss 3.8997, val loss 3.8056
# step 1900: train loss 3.7208, val loss 3.6809
# step 1910: train loss 3.7438, val loss 3.8246
# step 1920: train loss 3.7849, val loss 3.7443
# step 1930: train loss 3.7645, val loss 3.7461
# step 1940: train loss 3.7691, val loss 3.7455
# step 1950: train loss 3.8294, val loss 3.8371
# step 1960: train loss 3.7330, val loss 3.7224
# step 1970: train loss 3.7819, val loss 3.8104
# step 1980: train loss 3.7097, val loss 3.7354
# step 1990: train loss 3.6957, val loss 3.7016
# step 2000: train loss 3.7142, val loss 3.7465
# step 2010: train loss 3.7317, val loss 3.7148
# step 2020: train loss 3.6892, val loss 3.6627
# step 2030: train loss 3.6962, val loss 3.8366
# step 2040: train loss 3.6761, val loss 3.7480
# step 2050: train loss 3.7060, val loss 3.7002
# step 2060: train loss 3.6881, val loss 3.6870
# step 2070: train loss 3.6954, val loss 3.6806
# step 2080: train loss 3.6521, val loss 3.7569
# step 2090: train loss 3.7371, val loss 3.7793
# step 2100: train loss 3.6237, val loss 3.7017
# step 2110: train loss 3.6982, val loss 3.7589
# step 2120: train loss 3.6877, val loss 3.5857
# step 2130: train loss 3.6731, val loss 3.6757
# step 2140: train loss 3.6435, val loss 3.7231
# step 2150: train loss 3.6153, val loss 3.7552
# step 2160: train loss 3.6864, val loss 3.6970
# step 2170: train loss 3.6574, val loss 3.6108
# step 2180: train loss 3.6194, val loss 3.6576
# step 2190: train loss 3.5943, val loss 3.6730
# step 2200: train loss 3.6010, val loss 3.6790
# step 2210: train loss 3.6438, val loss 3.6939
# step 2220: train loss 3.6026, val loss 3.5448
# step 2230: train loss 3.6400, val loss 3.6913
# step 2240: train loss 3.6522, val loss 3.6512
# step 2250: train loss 3.5520, val loss 3.6372
# step 2260: train loss 3.5908, val loss 3.6716
# step 2270: train loss 3.6039, val loss 3.5860
# step 2280: train loss 3.5716, val loss 3.6265
# step 2290: train loss 3.6303, val loss 3.6045
# step 2300: train loss 3.6097, val loss 3.5786
# step 2310: train loss 3.6857, val loss 3.6167
# step 2320: train loss 3.5631, val loss 3.5542
# step 2330: train loss 3.5986, val loss 3.6503
# step 2340: train loss 3.5600, val loss 3.6658
# step 2350: train loss 3.5679, val loss 3.5571
# step 2360: train loss 3.5081, val loss 3.4791
# step 2370: train loss 3.6631, val loss 3.5857
# step 2380: train loss 3.5855, val loss 3.5123
# step 2390: train loss 3.5312, val loss 3.5647
# step 2400: train loss 3.5897, val loss 3.5149
# step 2410: train loss 3.5594, val loss 3.4929
# step 2420: train loss 3.5160, val loss 3.5257
# step 2430: train loss 3.5369, val loss 3.6039
# step 2440: train loss 3.5541, val loss 3.5371
# step 2450: train loss 3.4983, val loss 3.6184
# step 2460: train loss 3.5167, val loss 3.5098
# step 2470: train loss 3.4318, val loss 3.4909
# step 2480: train loss 3.5110, val loss 3.6393
# step 2490: train loss 3.4481, val loss 3.5247
# step 2500: train loss 3.4750, val loss 3.5078
# step 2510: train loss 3.4776, val loss 3.5785
# step 2520: train loss 3.4490, val loss 3.6133
# step 2530: train loss 3.5257, val loss 3.5315
# step 2540: train loss 3.3808, val loss 3.5639
# step 2550: train loss 3.5018, val loss 3.4181
# step 2560: train loss 3.4286, val loss 3.5258
# step 2570: train loss 3.4953, val loss 3.4703
# step 2580: train loss 3.4582, val loss 3.4887
# step 2590: train loss 3.4845, val loss 3.4842
# step 2600: train loss 3.4242, val loss 3.4799
# step 2610: train loss 3.4243, val loss 3.5290
# step 2620: train loss 3.4475, val loss 3.4682
# step 2630: train loss 3.4571, val loss 3.4144
# step 2640: train loss 3.4211, val loss 3.3949
# step 2650: train loss 3.4467, val loss 3.4576
# step 2660: train loss 3.4401, val loss 3.4558
# step 2670: train loss 3.5253, val loss 3.4459
# step 2680: train loss 3.4122, val loss 3.4517
# step 2690: train loss 3.4080, val loss 3.4696
# step 2700: train loss 3.4310, val loss 3.4191
# step 2710: train loss 3.4103, val loss 3.5112
# step 2720: train loss 3.4234, val loss 3.3994
# step 2730: train loss 3.4564, val loss 3.4790
# step 2740: train loss 3.3726, val loss 3.5079
# step 2750: train loss 3.3750, val loss 3.3640
# step 2760: train loss 3.4659, val loss 3.4744
# step 2770: train loss 3.3803, val loss 3.4345
# step 2780: train loss 3.3706, val loss 3.5301
# step 2790: train loss 3.3925, val loss 3.2969
# step 2800: train loss 3.3953, val loss 3.3854
# step 2810: train loss 3.3825, val loss 3.5132
# step 2820: train loss 3.2899, val loss 3.3418
# step 2830: train loss 3.3107, val loss 3.3766
# step 2840: train loss 3.3241, val loss 3.3771
# step 2850: train loss 3.3464, val loss 3.3994
# step 2860: train loss 3.4236, val loss 3.3459
# step 2870: train loss 3.4204, val loss 3.4358
# step 2880: train loss 3.2871, val loss 3.2664
# step 2890: train loss 3.4035, val loss 3.3485
# step 2900: train loss 3.4069, val loss 3.3189
# step 2910: train loss 3.3381, val loss 3.2981
# step 2920: train loss 3.3396, val loss 3.3401
# step 2930: train loss 3.2896, val loss 3.3985
# step 2940: train loss 3.2890, val loss 3.4914
# step 2950: train loss 3.3405, val loss 3.4155
# step 2960: train loss 3.2810, val loss 3.4303
# step 2970: train loss 3.3284, val loss 3.4066
# step 2980: train loss 3.3208, val loss 3.3010
# step 2990: train loss 3.2962, val loss 3.3122
# step 3000: train loss 3.2740, val loss 3.3556
# step 3010: train loss 3.2984, val loss 3.2690
# step 3020: train loss 3.3200, val loss 3.2836
# step 3030: train loss 3.2818, val loss 3.2920
# step 3040: train loss 3.3305, val loss 3.3444
# step 3050: train loss 3.2139, val loss 3.3195
# step 3060: train loss 3.2833, val loss 3.2390
# step 3070: train loss 3.3156, val loss 3.2175
# step 3080: train loss 3.2145, val loss 3.3462
# step 3090: train loss 3.2492, val loss 3.2722
# step 3100: train loss 3.3952, val loss 3.3108
# step 3110: train loss 3.3225, val loss 3.2779
# step 3120: train loss 3.1435, val loss 3.2884
# step 3130: train loss 3.2001, val loss 3.2634
# step 3140: train loss 3.2965, val loss 3.3566
# step 3150: train loss 3.2363, val loss 3.2787
# step 3160: train loss 3.2495, val loss 3.3153
# step 3170: train loss 3.2842, val loss 3.3229
# step 3180: train loss 3.2184, val loss 3.2177
# step 3190: train loss 3.2174, val loss 3.3146
# step 3200: train loss 3.1524, val loss 3.2936
# step 3210: train loss 3.3285, val loss 3.2892
# step 3220: train loss 3.2059, val loss 3.1919
# step 3230: train loss 3.2241, val loss 3.4148
# step 3240: train loss 3.2712, val loss 3.2177
# step 3250: train loss 3.2095, val loss 3.2812
# step 3260: train loss 3.2328, val loss 3.2438
# step 3270: train loss 3.3294, val loss 3.2185
# step 3280: train loss 3.2891, val loss 3.2350
# step 3290: train loss 3.1569, val loss 3.2744
# step 3300: train loss 3.1913, val loss 3.1929
# step 3310: train loss 3.1624, val loss 3.2036
# step 3320: train loss 3.1460, val loss 3.1729
# step 3330: train loss 3.1902, val loss 3.2353
# step 3340: train loss 3.2199, val loss 3.2173
# step 3350: train loss 3.2240, val loss 3.1915
# step 3360: train loss 3.1903, val loss 3.1806
# step 3370: train loss 3.1314, val loss 3.3370
# step 3380: train loss 3.2075, val loss 3.2457
# step 3390: train loss 3.1269, val loss 3.2071
# step 3400: train loss 3.1862, val loss 3.2119
# step 3410: train loss 3.1930, val loss 3.1834
# step 3420: train loss 3.0886, val loss 3.1630
# step 3430: train loss 3.1848, val loss 3.1935
# step 3440: train loss 3.1352, val loss 3.2111
# step 3450: train loss 3.1219, val loss 3.2083
# step 3460: train loss 3.2004, val loss 3.2240
# step 3470: train loss 3.1364, val loss 3.1947
# step 3480: train loss 3.1990, val loss 3.2253
# step 3490: train loss 3.1957, val loss 3.2327
# step 3500: train loss 3.0968, val loss 3.1296
# step 3510: train loss 3.1015, val loss 3.2747
# step 3520: train loss 3.1311, val loss 3.2318
# step 3530: train loss 3.1286, val loss 3.2574
# step 3540: train loss 3.1465, val loss 3.1313
# step 3550: train loss 3.1412, val loss 3.1801
# step 3560: train loss 3.1703, val loss 3.1736
# step 3570: train loss 3.2423, val loss 3.2456
# step 3580: train loss 3.0918, val loss 3.2130
# step 3590: train loss 3.1704, val loss 3.1878
# step 3600: train loss 3.1375, val loss 3.0564
# step 3610: train loss 3.1492, val loss 3.2310
# step 3620: train loss 3.0319, val loss 3.0820
# step 3630: train loss 3.1600, val loss 3.1275
# step 3640: train loss 3.0881, val loss 3.2032
# step 3650: train loss 3.1373, val loss 3.1281
# step 3660: train loss 3.0568, val loss 3.0095
# step 3670: train loss 3.1468, val loss 3.2232
# step 3680: train loss 3.0814, val loss 3.2093
# step 3690: train loss 3.0564, val loss 3.0847
# step 3700: train loss 3.0917, val loss 3.1672
# step 3710: train loss 3.0799, val loss 3.1840
# step 3720: train loss 3.0433, val loss 3.1702
# step 3730: train loss 3.0700, val loss 3.0940
# step 3740: train loss 3.0414, val loss 3.1340
# step 3750: train loss 3.0445, val loss 3.1135
# step 3760: train loss 3.0780, val loss 3.0703
# step 3770: train loss 3.0168, val loss 3.0702
# step 3780: train loss 3.0548, val loss 3.0860
# step 3790: train loss 3.0206, val loss 3.1033
# step 3800: train loss 3.0860, val loss 3.0704
# step 3810: train loss 3.0091, val loss 3.1378
# step 3820: train loss 3.0583, val loss 3.1379
# step 3830: train loss 3.0919, val loss 3.1358
# step 3840: train loss 3.1207, val loss 3.0595
# step 3850: train loss 3.0693, val loss 3.0989
# step 3860: train loss 3.0129, val loss 3.0601
# step 3870: train loss 3.1415, val loss 3.0848
# step 3880: train loss 3.0131, val loss 3.1213
# step 3890: train loss 3.0440, val loss 3.1049
# step 3900: train loss 2.9736, val loss 3.0621
# step 3910: train loss 3.0690, val loss 3.1902
# step 3920: train loss 3.0099, val loss 3.1842
# step 3930: train loss 3.0776, val loss 3.1244
# step 3940: train loss 3.0519, val loss 3.0671
# step 3950: train loss 3.0376, val loss 3.1363
# step 3960: train loss 3.0018, val loss 3.0612
# step 3970: train loss 3.1301, val loss 3.1162
# step 3980: train loss 3.0285, val loss 3.0145
# step 3990: train loss 3.0504, val loss 3.0378
# step 4000: train loss 3.0537, val loss 3.0702
# step 4010: train loss 3.0187, val loss 3.0438
# step 4020: train loss 3.0644, val loss 3.0277
# step 4030: train loss 3.0615, val loss 3.0668
# step 4040: train loss 2.9640, val loss 3.0549
# step 4050: train loss 3.0398, val loss 3.0551
# step 4060: train loss 3.0147, val loss 3.0905
# step 4070: train loss 2.9830, val loss 3.0577
# step 4080: train loss 3.0002, val loss 3.0436
# step 4090: train loss 2.9599, val loss 3.1300
# step 4100: train loss 3.0266, val loss 3.0294
# step 4110: train loss 3.0229, val loss 2.9911
# step 4120: train loss 3.0275, val loss 3.0475
# step 4130: train loss 2.9556, val loss 3.0059
# step 4140: train loss 3.0056, val loss 3.0898
# step 4150: train loss 2.9722, val loss 3.0071
# step 4160: train loss 2.9348, val loss 3.0250
# step 4170: train loss 3.0160, val loss 3.0617
# step 4180: train loss 3.0022, val loss 3.0292
# step 4190: train loss 3.0071, val loss 3.1066
# step 4200: train loss 2.9698, val loss 3.0091
# step 4210: train loss 3.0166, val loss 2.9146
# step 4220: train loss 3.0453, val loss 2.9176
# step 4230: train loss 2.9485, val loss 3.0383
# step 4240: train loss 3.0224, val loss 2.9752
# step 4250: train loss 2.9904, val loss 3.0032
# step 4260: train loss 2.9381, val loss 3.1088
# step 4270: train loss 2.9452, val loss 3.0726
# step 4280: train loss 2.9336, val loss 3.0078
# step 4290: train loss 2.9804, val loss 3.0318
# step 4300: train loss 2.9493, val loss 3.0060
# step 4310: train loss 2.9685, val loss 3.0467
# step 4320: train loss 2.9139, val loss 2.9363
# step 4330: train loss 2.9088, val loss 3.0029
# step 4340: train loss 2.9618, val loss 2.9998
# step 4350: train loss 2.8865, val loss 2.9641
# step 4360: train loss 2.9961, val loss 3.0246
# step 4370: train loss 2.9514, val loss 3.0140
# step 4380: train loss 2.9085, val loss 3.0795
# step 4390: train loss 2.9410, val loss 3.0256
# step 4400: train loss 2.9535, val loss 2.9369
# step 4410: train loss 2.8454, val loss 2.9798
# step 4420: train loss 2.9176, val loss 2.9995
# step 4430: train loss 2.9319, val loss 2.9693
# step 4440: train loss 2.9202, val loss 2.9046
# step 4450: train loss 2.9304, val loss 2.9914
# step 4460: train loss 2.8962, val loss 2.9198
# step 4470: train loss 2.9077, val loss 3.0113
# step 4480: train loss 2.8803, val loss 2.8744
# step 4490: train loss 2.9669, val loss 2.9367
# step 4500: train loss 2.9140, val loss 3.0141
# step 4510: train loss 2.9815, val loss 2.9094
# step 4520: train loss 2.9245, val loss 3.0759
# step 4530: train loss 2.9233, val loss 2.9281
# step 4540: train loss 2.9585, val loss 2.9801
# step 4550: train loss 2.9888, val loss 3.0796
# step 4560: train loss 2.8612, val loss 2.9562
# step 4570: train loss 2.8762, val loss 2.9551
# step 4580: train loss 2.9473, val loss 2.9184
# step 4590: train loss 2.8660, val loss 2.9020
# step 4600: train loss 2.8363, val loss 2.8680
# step 4610: train loss 2.8921, val loss 2.9605
# step 4620: train loss 2.8436, val loss 3.0757
# step 4630: train loss 2.8450, val loss 2.9118
# step 4640: train loss 2.8977, val loss 2.9201
# step 4650: train loss 2.8831, val loss 2.9614
# step 4660: train loss 2.9837, val loss 3.0265
# step 4670: train loss 2.8733, val loss 2.9883
# step 4680: train loss 2.9319, val loss 3.0794
# step 4690: train loss 2.8764, val loss 2.9157
# step 4700: train loss 2.8493, val loss 2.9081
# step 4710: train loss 2.8731, val loss 2.9986
# step 4720: train loss 2.8787, val loss 2.9666
# step 4730: train loss 2.9116, val loss 2.8802
# step 4740: train loss 2.9026, val loss 2.9004
# step 4750: train loss 2.8576, val loss 2.8966
# step 4760: train loss 2.8090, val loss 2.7673
# step 4770: train loss 2.8443, val loss 2.9387
# step 4780: train loss 2.8011, val loss 2.9497
# step 4790: train loss 2.8709, val loss 2.8793
# step 4800: train loss 2.9210, val loss 2.7573
# step 4810: train loss 2.8880, val loss 2.8903
# step 4820: train loss 2.8976, val loss 2.8492
# step 4830: train loss 2.7827, val loss 2.8482
# step 4840: train loss 2.8096, val loss 2.8480
# step 4850: train loss 2.9428, val loss 2.8772
# step 4860: train loss 2.8257, val loss 2.9774
# step 4870: train loss 2.8256, val loss 2.7983
# step 4880: train loss 2.8099, val loss 2.9057
# step 4890: train loss 2.8271, val loss 2.9153
# step 4900: train loss 2.8678, val loss 2.9050
# step 4910: train loss 2.7820, val loss 2.8777
# step 4920: train loss 2.8272, val loss 2.8619
# step 4930: train loss 2.8315, val loss 2.8655
# step 4940: train loss 2.8592, val loss 2.8972
# step 4950: train loss 2.8354, val loss 2.8980
# step 4960: train loss 2.8682, val loss 2.9659
# step 4970: train loss 2.8648, val loss 2.9172
# step 4980: train loss 2.8867, val loss 2.9118
# step 4990: train loss 2.8866, val loss 2.8406
# step 5000: train loss 2.8994, val loss 2.8407
# step 5010: train loss 2.8063, val loss 2.8687
# step 5020: train loss 2.8308, val loss 2.8134
# step 5030: train loss 2.7730, val loss 3.0726
# step 5040: train loss 2.7797, val loss 2.7843
# step 5050: train loss 2.8509, val loss 2.8053
# step 5060: train loss 2.8237, val loss 2.9136
# step 5070: train loss 2.8175, val loss 2.8144
# step 5080: train loss 2.8195, val loss 2.8778
# step 5090: train loss 2.9105, val loss 2.9577
# step 5100: train loss 2.7809, val loss 2.9250
# step 5110: train loss 2.7296, val loss 2.9397
# step 5120: train loss 2.8252, val loss 2.8207
# step 5130: train loss 2.8142, val loss 3.0011
# step 5140: train loss 2.7887, val loss 2.7808
# step 5150: train loss 2.7528, val loss 2.9458
# step 5160: train loss 2.8762, val loss 2.8543
# step 5170: train loss 2.8498, val loss 2.8317
# step 5180: train loss 2.7904, val loss 2.9325
# step 5190: train loss 2.7817, val loss 2.8380
# step 5200: train loss 2.7609, val loss 2.8051
# step 5210: train loss 2.7298, val loss 2.8027
# step 5220: train loss 2.7735, val loss 2.8437
# step 5230: train loss 2.8063, val loss 2.8865
# step 5240: train loss 2.7991, val loss 2.8455
# step 5250: train loss 2.8014, val loss 2.9211
# step 5260: train loss 2.8237, val loss 2.8752
# step 5270: train loss 2.8359, val loss 2.8718
# step 5280: train loss 2.7900, val loss 2.8239
# step 5290: train loss 2.7500, val loss 2.8556
# step 5300: train loss 2.7227, val loss 2.8364
# step 5310: train loss 2.7985, val loss 2.8561
# step 5320: train loss 2.7468, val loss 2.8460
# step 5330: train loss 2.7499, val loss 2.8192
# step 5340: train loss 2.7975, val loss 2.7606
# step 5350: train loss 2.8028, val loss 2.8945
# step 5360: train loss 2.7689, val loss 2.8551
# step 5370: train loss 2.8113, val loss 2.8189
# step 5380: train loss 2.8527, val loss 2.8620
# step 5390: train loss 2.7311, val loss 2.8805
# step 5400: train loss 2.8071, val loss 3.0123
# step 5410: train loss 2.7811, val loss 2.8505
# step 5420: train loss 2.8413, val loss 2.7986
# step 5430: train loss 2.7321, val loss 2.8634
# step 5440: train loss 2.7886, val loss 2.7758
# step 5450: train loss 2.7726, val loss 2.8598
# step 5460: train loss 2.7769, val loss 2.9144
# step 5470: train loss 2.8423, val loss 2.8090
# step 5480: train loss 2.7634, val loss 2.7544
# step 5490: train loss 2.8014, val loss 2.8019
# step 5500: train loss 2.8030, val loss 2.8578
# step 5510: train loss 2.7445, val loss 2.7747
# step 5520: train loss 2.8166, val loss 2.8611
# step 5530: train loss 2.8239, val loss 2.7911
# step 5540: train loss 2.7911, val loss 2.6827
# step 5550: train loss 2.7761, val loss 2.7885
# step 5560: train loss 2.7695, val loss 2.9223
# step 5570: train loss 2.8053, val loss 2.8362
# step 5580: train loss 2.7318, val loss 2.8368
# step 5590: train loss 2.7793, val loss 2.8192
# step 5600: train loss 2.7622, val loss 2.8062
# step 5610: train loss 2.7308, val loss 2.7792
# step 5620: train loss 2.7563, val loss 2.7213
# step 5630: train loss 2.7728, val loss 2.8759
# step 5640: train loss 2.7562, val loss 2.7597
# step 5650: train loss 2.7239, val loss 2.7064
# step 5660: train loss 2.8015, val loss 2.7877
# step 5670: train loss 2.7411, val loss 2.7974
# step 5680: train loss 2.7691, val loss 2.7275
# step 5690: train loss 2.7191, val loss 2.8849
# step 5700: train loss 2.7219, val loss 2.7567
# step 5710: train loss 2.7635, val loss 2.7596
# step 5720: train loss 2.7379, val loss 2.7489
# step 5730: train loss 2.7755, val loss 2.8967
# step 5740: train loss 2.7970, val loss 2.8155
# step 5750: train loss 2.7097, val loss 2.7747
# step 5760: train loss 2.6858, val loss 2.8157
# step 5770: train loss 2.6508, val loss 2.7674
# step 5780: train loss 2.7293, val loss 2.8148
# step 5790: train loss 2.7263, val loss 2.7723
# step 5800: train loss 2.7414, val loss 2.8083
# step 5810: train loss 2.7248, val loss 2.8659
# step 5820: train loss 2.6559, val loss 2.7687
# step 5830: train loss 2.7056, val loss 2.8727
# step 5840: train loss 2.7322, val loss 2.7546
# step 5850: train loss 2.7515, val loss 2.7837
# step 5860: train loss 2.6976, val loss 2.9234
# step 5870: train loss 2.6805, val loss 2.8135
# step 5880: train loss 2.7601, val loss 2.7024
# step 5890: train loss 2.8076, val loss 2.7412
# step 5900: train loss 2.8274, val loss 2.8225
# step 5910: train loss 2.6681, val loss 2.7546
# step 5920: train loss 2.7379, val loss 2.8459
# step 5930: train loss 2.7113, val loss 2.7113
# step 5940: train loss 2.7146, val loss 2.7832
# step 5950: train loss 2.7129, val loss 2.7200
# step 5960: train loss 2.8010, val loss 2.7218
# step 5970: train loss 2.7379, val loss 2.7810
# step 5980: train loss 2.7041, val loss 2.7969
# step 5990: train loss 2.8248, val loss 2.6911
# step 6000: train loss 2.6843, val loss 2.8560
# step 6010: train loss 2.7192, val loss 2.7231
# step 6020: train loss 2.7111, val loss 2.8037
# step 6030: train loss 2.6413, val loss 2.7640
# step 6040: train loss 2.6881, val loss 2.7876
# step 6050: train loss 2.6893, val loss 2.7841
# step 6060: train loss 2.7136, val loss 2.7117
# step 6070: train loss 2.7409, val loss 2.7458
# step 6080: train loss 2.7699, val loss 2.7150
# step 6090: train loss 2.7151, val loss 2.7611
# step 6100: train loss 2.6643, val loss 2.7081
# step 6110: train loss 2.6314, val loss 2.7817
# step 6120: train loss 2.5880, val loss 2.8155
# step 6130: train loss 2.5990, val loss 2.7130
# step 6140: train loss 2.8137, val loss 2.7972
# step 6150: train loss 2.6518, val loss 2.7948
# step 6160: train loss 2.6251, val loss 2.7797
# step 6170: train loss 2.7190, val loss 2.7682
# step 6180: train loss 2.6541, val loss 2.8274
# step 6190: train loss 2.6860, val loss 2.7648
# step 6200: train loss 2.7095, val loss 2.8023
# step 6210: train loss 2.7252, val loss 2.6541
# step 6220: train loss 2.6816, val loss 2.7345
# step 6230: train loss 2.7043, val loss 2.7625
# step 6240: train loss 2.6079, val loss 2.7719
# step 6250: train loss 2.6704, val loss 2.7186
# step 6260: train loss 2.6009, val loss 2.8416
# step 6270: train loss 2.7025, val loss 2.8028
# step 6280: train loss 2.6942, val loss 2.6495
# step 6290: train loss 2.6648, val loss 2.7893
# step 6300: train loss 2.6624, val loss 2.7755
# step 6310: train loss 2.6887, val loss 2.6678
# step 6320: train loss 2.7223, val loss 2.7705
# step 6330: train loss 2.6944, val loss 2.8255
# step 6340: train loss 2.6443, val loss 2.7812
# step 6350: train loss 2.6833, val loss 2.7892
# step 6360: train loss 2.7404, val loss 2.7195
# step 6370: train loss 2.6437, val loss 2.7132
# step 6380: train loss 2.7220, val loss 2.7303
# step 6390: train loss 2.7074, val loss 2.8789
# step 6400: train loss 2.6862, val loss 2.7122
# step 6410: train loss 2.7175, val loss 2.7440
# step 6420: train loss 2.7074, val loss 2.7343
# step 6430: train loss 2.6570, val loss 2.7064
# step 6440: train loss 2.6946, val loss 2.7030
# step 6450: train loss 2.7488, val loss 2.8550
# step 6460: train loss 2.7153, val loss 2.7808
# step 6470: train loss 2.6129, val loss 2.6647
# step 6480: train loss 2.6639, val loss 2.7388
# step 6490: train loss 2.7350, val loss 2.6914
# step 6500: train loss 2.5911, val loss 2.8171
# step 6510: train loss 2.6643, val loss 2.7186
# step 6520: train loss 2.6834, val loss 2.6701
# step 6530: train loss 2.6299, val loss 2.8420
# step 6540: train loss 2.6170, val loss 2.6680
# step 6550: train loss 2.6243, val loss 2.7396
# step 6560: train loss 2.6172, val loss 2.8527
# step 6570: train loss 2.6967, val loss 2.7176
# step 6580: train loss 2.6108, val loss 2.7996
# step 6590: train loss 2.7146, val loss 2.7144
# step 6600: train loss 2.6514, val loss 2.6918
# step 6610: train loss 2.6222, val loss 2.7934
# step 6620: train loss 2.6866, val loss 2.7131
# step 6630: train loss 2.6740, val loss 2.7104
# step 6640: train loss 2.7304, val loss 2.6915
# step 6650: train loss 2.6130, val loss 2.7305
# step 6660: train loss 2.6966, val loss 2.8278
# step 6670: train loss 2.7349, val loss 2.6995
# step 6680: train loss 2.6481, val loss 2.7440
# step 6690: train loss 2.6782, val loss 2.5721
# step 6700: train loss 2.6869, val loss 2.6560
# step 6710: train loss 2.6586, val loss 2.6743
# step 6720: train loss 2.6518, val loss 2.7214
# step 6730: train loss 2.6310, val loss 2.6195
# step 6740: train loss 2.6888, val loss 2.7864
# step 6750: train loss 2.6121, val loss 2.6108
# step 6760: train loss 2.6599, val loss 2.7766
# step 6770: train loss 2.6232, val loss 2.7081
# step 6780: train loss 2.6483, val loss 2.6970
# step 6790: train loss 2.6127, val loss 2.7008
# step 6800: train loss 2.6436, val loss 2.7323
# step 6810: train loss 2.7134, val loss 2.7104
# step 6820: train loss 2.4986, val loss 2.7215
# step 6830: train loss 2.6399, val loss 2.6882
# step 6840: train loss 2.5925, val loss 2.6886
# step 6850: train loss 2.7088, val loss 2.7149
# step 6860: train loss 2.6038, val loss 2.6468
# step 6870: train loss 2.6664, val loss 2.7211
# step 6880: train loss 2.6324, val loss 2.7582
# step 6890: train loss 2.6699, val loss 2.7473
# step 6900: train loss 2.7015, val loss 2.5455
# step 6910: train loss 2.6703, val loss 2.6758
# step 6920: train loss 2.6262, val loss 2.6915
# step 6930: train loss 2.6429, val loss 2.6682
# step 6940: train loss 2.6608, val loss 2.7112
# step 6950: train loss 2.6108, val loss 2.6604
# step 6960: train loss 2.6926, val loss 2.7687
# step 6970: train loss 2.7006, val loss 2.6590
# step 6980: train loss 2.6840, val loss 2.7490
# step 6990: train loss 2.7041, val loss 2.7824
# step 7000: train loss 2.6173, val loss 2.6481
# step 7010: train loss 2.6839, val loss 2.6706
# step 7020: train loss 2.6748, val loss 2.6263
# step 7030: train loss 2.6504, val loss 2.7889
# step 7040: train loss 2.4989, val loss 2.7416
# step 7050: train loss 2.5587, val loss 2.6325
# step 7060: train loss 2.6640, val loss 2.6969
# step 7070: train loss 2.5691, val loss 2.7049
# step 7080: train loss 2.5865, val loss 2.5919
# step 7090: train loss 2.6736, val loss 2.6935
# step 7100: train loss 2.5993, val loss 2.6893
# step 7110: train loss 2.6355, val loss 2.7601
# step 7120: train loss 2.6776, val loss 2.6926
# step 7130: train loss 2.6129, val loss 2.6443
# step 7140: train loss 2.5341, val loss 2.7309
# step 7150: train loss 2.6261, val loss 2.6007
# step 7160: train loss 2.6368, val loss 2.6888
# step 7170: train loss 2.5771, val loss 2.8287
# step 7180: train loss 2.5879, val loss 2.7151
# step 7190: train loss 2.6543, val loss 2.7563
# step 7200: train loss 2.6275, val loss 2.6885
# step 7210: train loss 2.5452, val loss 2.7580
# step 7220: train loss 2.6353, val loss 2.6614
# step 7230: train loss 2.6413, val loss 2.6698
# step 7240: train loss 2.5687, val loss 2.6446
# step 7250: train loss 2.6441, val loss 2.6877
# step 7260: train loss 2.6099, val loss 2.6767
# step 7270: train loss 2.6844, val loss 2.7208
# step 7280: train loss 2.5280, val loss 2.6915
# step 7290: train loss 2.6615, val loss 2.7049
# step 7300: train loss 2.5340, val loss 2.6726
# step 7310: train loss 2.6057, val loss 2.6623
# step 7320: train loss 2.6303, val loss 2.7273
# step 7330: train loss 2.5748, val loss 2.5974
# step 7340: train loss 2.5473, val loss 2.7018
# step 7350: train loss 2.6586, val loss 2.6650
# step 7360: train loss 2.5621, val loss 2.7038
# step 7370: train loss 2.6119, val loss 2.6419
# step 7380: train loss 2.5439, val loss 2.7438
# step 7390: train loss 2.6439, val loss 2.5806
# step 7400: train loss 2.6354, val loss 2.6969
# step 7410: train loss 2.5883, val loss 2.5733
# step 7420: train loss 2.6767, val loss 2.6685
# step 7430: train loss 2.6458, val loss 2.7751
# step 7440: train loss 2.5459, val loss 2.6473
# step 7450: train loss 2.5845, val loss 2.6437
# step 7460: train loss 2.6388, val loss 2.6521
# step 7470: train loss 2.6064, val loss 2.6085
# step 7480: train loss 2.6016, val loss 2.6331
# step 7490: train loss 2.5296, val loss 2.6198
# step 7500: train loss 2.5417, val loss 2.6542
# step 7510: train loss 2.6595, val loss 2.6728
# step 7520: train loss 2.5903, val loss 2.7653
# step 7530: train loss 2.5543, val loss 2.6764
# step 7540: train loss 2.5562, val loss 2.6110
# step 7550: train loss 2.5852, val loss 2.6873
# step 7560: train loss 2.5380, val loss 2.6762
# step 7570: train loss 2.5437, val loss 2.6950
# step 7580: train loss 2.5310, val loss 2.7220
# step 7590: train loss 2.5764, val loss 2.7343
# step 7600: train loss 2.6377, val loss 2.6863
# step 7610: train loss 2.6114, val loss 2.6515
# step 7620: train loss 2.6236, val loss 2.6194
# step 7630: train loss 2.6196, val loss 2.7061
# step 7640: train loss 2.5624, val loss 2.6129
# step 7650: train loss 2.5901, val loss 2.6200
# step 7660: train loss 2.6012, val loss 2.5334
# step 7670: train loss 2.5335, val loss 2.6810
# step 7680: train loss 2.5517, val loss 2.7111
# step 7690: train loss 2.4999, val loss 2.6285
# step 7700: train loss 2.5529, val loss 2.5717
# step 7710: train loss 2.5673, val loss 2.6490
# step 7720: train loss 2.6020, val loss 2.5686
# step 7730: train loss 2.5744, val loss 2.6064
# step 7740: train loss 2.5723, val loss 2.6846
# step 7750: train loss 2.6816, val loss 2.6390
# step 7760: train loss 2.5417, val loss 2.6033
# step 7770: train loss 2.5643, val loss 2.6295
# step 7780: train loss 2.6571, val loss 2.7171
# step 7790: train loss 2.6023, val loss 2.5689
# step 7800: train loss 2.6212, val loss 2.6475
# step 7810: train loss 2.5840, val loss 2.5374
# step 7820: train loss 2.6499, val loss 2.7565
# step 7830: train loss 2.5485, val loss 2.7086
# step 7840: train loss 2.5732, val loss 2.6483
# step 7850: train loss 2.5628, val loss 2.6814
# step 7860: train loss 2.5443, val loss 2.7442
# step 7870: train loss 2.6017, val loss 2.5871
# step 7880: train loss 2.5561, val loss 2.5211
# step 7890: train loss 2.5645, val loss 2.5949
# step 7900: train loss 2.5549, val loss 2.5701
# step 7910: train loss 2.6544, val loss 2.6745
# step 7920: train loss 2.5067, val loss 2.6832
# step 7930: train loss 2.6676, val loss 2.7158
# step 7940: train loss 2.5918, val loss 2.6785
# step 7950: train loss 2.5944, val loss 2.6288
# step 7960: train loss 2.6041, val loss 2.5496
# step 7970: train loss 2.5590, val loss 2.5741
# step 7980: train loss 2.5853, val loss 2.6654
# step 7990: train loss 2.5975, val loss 2.5907
# step 8000: train loss 2.5532, val loss 2.6971
# step 8010: train loss 2.5594, val loss 2.5320
# step 8020: train loss 2.5792, val loss 2.6153
# step 8030: train loss 2.5809, val loss 2.5272
# step 8040: train loss 2.5572, val loss 2.6175
# step 8050: train loss 2.5593, val loss 2.6847
# step 8060: train loss 2.5100, val loss 2.6654
# step 8070: train loss 2.5617, val loss 2.5899
# step 8080: train loss 2.5279, val loss 2.6311
# step 8090: train loss 2.6042, val loss 2.5736
# step 8100: train loss 2.5751, val loss 2.6390
# step 8110: train loss 2.5450, val loss 2.6603
# step 8120: train loss 2.4858, val loss 2.5806
# step 8130: train loss 2.5116, val loss 2.5983
# step 8140: train loss 2.6004, val loss 2.5473
# step 8150: train loss 2.5437, val loss 2.5613
# step 8160: train loss 2.5923, val loss 2.5279
# step 8170: train loss 2.5815, val loss 2.6941
# step 8180: train loss 2.6314, val loss 2.7135
# step 8190: train loss 2.5688, val loss 2.6171
# step 8200: train loss 2.5494, val loss 2.5587
# step 8210: train loss 2.6211, val loss 2.5556
# step 8220: train loss 2.5366, val loss 2.4916
# step 8230: train loss 2.5770, val loss 2.5248
# step 8240: train loss 2.6156, val loss 2.5708
# step 8250: train loss 2.5694, val loss 2.6090
# step 8260: train loss 2.5559, val loss 2.6058
# step 8270: train loss 2.5896, val loss 2.6241
# step 8280: train loss 2.5469, val loss 2.6811
# step 8290: train loss 2.4996, val loss 2.5691
# step 8300: train loss 2.5427, val loss 2.5717
# step 8310: train loss 2.5251, val loss 2.5805
# step 8320: train loss 2.5737, val loss 2.6468
# step 8330: train loss 2.5823, val loss 2.5762
# step 8340: train loss 2.5626, val loss 2.6841
# step 8350: train loss 2.5394, val loss 2.6616
# step 8360: train loss 2.4724, val loss 2.7203
# step 8370: train loss 2.5766, val loss 2.6810
# step 8380: train loss 2.5849, val loss 2.7174
# step 8390: train loss 2.5767, val loss 2.6392
# step 8400: train loss 2.5447, val loss 2.6047
# step 8410: train loss 2.5808, val loss 2.6900
# step 8420: train loss 2.4941, val loss 2.6689
# step 8430: train loss 2.5497, val loss 2.7042
# step 8440: train loss 2.5833, val loss 2.5807
# step 8450: train loss 2.6285, val loss 2.6283
# step 8460: train loss 2.5600, val loss 2.5437
# step 8470: train loss 2.5359, val loss 2.5980
# step 8480: train loss 2.5256, val loss 2.5955
# step 8490: train loss 2.5638, val loss 2.5830
# step 8500: train loss 2.5879, val loss 2.6158
# step 8510: train loss 2.4935, val loss 2.6338
# step 8520: train loss 2.6263, val loss 2.5770
# step 8530: train loss 2.5547, val loss 2.6025
# step 8540: train loss 2.5224, val loss 2.6024
# step 8550: train loss 2.5440, val loss 2.5424
# step 8560: train loss 2.5176, val loss 2.5501
# step 8570: train loss 2.5093, val loss 2.6684
# step 8580: train loss 2.5853, val loss 2.6538
# step 8590: train loss 2.5656, val loss 2.7002
# step 8600: train loss 2.5271, val loss 2.5743
# step 8610: train loss 2.5270, val loss 2.5304
# step 8620: train loss 2.5784, val loss 2.6339
# step 8630: train loss 2.5509, val loss 2.5240
# step 8640: train loss 2.5282, val loss 2.5925
# step 8650: train loss 2.5355, val loss 2.4918
# step 8660: train loss 2.6276, val loss 2.5680
# step 8670: train loss 2.4728, val loss 2.5959
# step 8680: train loss 2.5266, val loss 2.6120
# step 8690: train loss 2.6139, val loss 2.5355
# step 8700: train loss 2.5582, val loss 2.6752
# step 8710: train loss 2.5369, val loss 2.7002
# step 8720: train loss 2.6780, val loss 2.6677
# step 8730: train loss 2.5478, val loss 2.6049
# step 8740: train loss 2.5949, val loss 2.5377
# step 8750: train loss 2.5043, val loss 2.4279
# step 8760: train loss 2.6131, val loss 2.6090
# step 8770: train loss 2.5083, val loss 2.6864
# step 8780: train loss 2.5743, val loss 2.6186
# step 8790: train loss 2.5270, val loss 2.6007
# step 8800: train loss 2.5924, val loss 2.5501
# step 8810: train loss 2.4969, val loss 2.6361
# step 8820: train loss 2.5492, val loss 2.7670
# step 8830: train loss 2.5465, val loss 2.6548
# step 8840: train loss 2.3908, val loss 2.5620
# step 8850: train loss 2.4975, val loss 2.6245
# step 8860: train loss 2.5606, val loss 2.5684
# step 8870: train loss 2.5597, val loss 2.8278
# step 8880: train loss 2.5709, val loss 2.6762
# step 8890: train loss 2.5836, val loss 2.6040
# step 8900: train loss 2.5167, val loss 2.6366
# step 8910: train loss 2.5195, val loss 2.5074
# step 8920: train loss 2.5590, val loss 2.6829
# step 8930: train loss 2.5109, val loss 2.4983
# step 8940: train loss 2.5601, val loss 2.6657
# step 8950: train loss 2.5781, val loss 2.5414
# step 8960: train loss 2.5246, val loss 2.6258
# step 8970: train loss 2.5139, val loss 2.4970
# step 8980: train loss 2.5466, val loss 2.5189
# step 8990: train loss 2.5290, val loss 2.5700
# step 9000: train loss 2.5180, val loss 2.5883
# step 9010: train loss 2.5109, val loss 2.6388
# step 9020: train loss 2.5146, val loss 2.5721
# step 9030: train loss 2.5502, val loss 2.5960
# step 9040: train loss 2.4878, val loss 2.5938
# step 9050: train loss 2.4650, val loss 2.7118
# step 9060: train loss 2.4807, val loss 2.5114
# step 9070: train loss 2.5577, val loss 2.6244
# step 9080: train loss 2.4949, val loss 2.5793
# step 9090: train loss 2.5677, val loss 2.6009
# step 9100: train loss 2.4561, val loss 2.5703
# step 9110: train loss 2.4847, val loss 2.5104
# step 9120: train loss 2.6104, val loss 2.6253
# step 9130: train loss 2.4934, val loss 2.6034
# step 9140: train loss 2.5245, val loss 2.6084
# step 9150: train loss 2.5195, val loss 2.6008
# step 9160: train loss 2.5812, val loss 2.5613
# step 9170: train loss 2.4821, val loss 2.4569
# step 9180: train loss 2.5135, val loss 2.5473
# step 9190: train loss 2.5019, val loss 2.5203
# step 9200: train loss 2.4911, val loss 2.6257
# step 9210: train loss 2.5474, val loss 2.5632
# step 9220: train loss 2.4526, val loss 2.5864
# step 9230: train loss 2.5231, val loss 2.6664
# step 9240: train loss 2.5348, val loss 2.4713
# step 9250: train loss 2.5058, val loss 2.5499
# step 9260: train loss 2.5655, val loss 2.6029
# step 9270: train loss 2.4921, val loss 2.6852
# step 9280: train loss 2.5069, val loss 2.5156
# step 9290: train loss 2.4965, val loss 2.5548
# step 9300: train loss 2.5487, val loss 2.5525
# step 9310: train loss 2.5421, val loss 2.6234
# step 9320: train loss 2.5688, val loss 2.5666
# step 9330: train loss 2.4775, val loss 2.6095
# step 9340: train loss 2.5475, val loss 2.5711
# step 9350: train loss 2.4996, val loss 2.5098
# step 9360: train loss 2.5311, val loss 2.5766
# step 9370: train loss 2.5009, val loss 2.5450
# step 9380: train loss 2.5275, val loss 2.4887
# step 9390: train loss 2.5045, val loss 2.6024
# step 9400: train loss 2.5453, val loss 2.5761
# step 9410: train loss 2.4971, val loss 2.5891
# step 9420: train loss 2.5641, val loss 2.4553
# step 9430: train loss 2.4390, val loss 2.5630
# step 9440: train loss 2.5013, val loss 2.6587
# step 9450: train loss 2.4882, val loss 2.5204
# step 9460: train loss 2.5176, val loss 2.6513
# step 9470: train loss 2.5741, val loss 2.5416
# step 9480: train loss 2.4952, val loss 2.5601
# step 9490: train loss 2.5368, val loss 2.5639
# step 9500: train loss 2.5532, val loss 2.4815
# step 9510: train loss 2.4629, val loss 2.6298
# step 9520: train loss 2.4836, val loss 2.7831
# step 9530: train loss 2.5012, val loss 2.5870
# step 9540: train loss 2.5236, val loss 2.4862
# step 9550: train loss 2.4978, val loss 2.5676
# step 9560: train loss 2.5019, val loss 2.4803
# step 9570: train loss 2.5182, val loss 2.5691
# step 9580: train loss 2.5521, val loss 2.4023
# step 9590: train loss 2.6176, val loss 2.6174
# step 9600: train loss 2.5196, val loss 2.5354
# step 9610: train loss 2.4929, val loss 2.5061
# step 9620: train loss 2.5008, val loss 2.6250
# step 9630: train loss 2.4856, val loss 2.6245
# step 9640: train loss 2.5232, val loss 2.5498
# step 9650: train loss 2.5051, val loss 2.4855
# step 9660: train loss 2.4838, val loss 2.5206
# step 9670: train loss 2.4876, val loss 2.5573
# step 9680: train loss 2.5792, val loss 2.5750
# step 9690: train loss 2.4339, val loss 2.5969
# step 9700: train loss 2.5511, val loss 2.5343
# step 9710: train loss 2.4639, val loss 2.6423
# step 9720: train loss 2.4738, val loss 2.5824
# step 9730: train loss 2.5187, val loss 2.5902
# step 9740: train loss 2.3961, val loss 2.5503
# step 9750: train loss 2.4800, val loss 2.4730
# step 9760: train loss 2.4886, val loss 2.5299
# step 9770: train loss 2.4337, val loss 2.8104
# step 9780: train loss 2.5135, val loss 2.7234
# step 9790: train loss 2.5431, val loss 2.6143
# step 9800: train loss 2.4536, val loss 2.5628
# step 9810: train loss 2.5199, val loss 2.5528
# step 9820: train loss 2.4773, val loss 2.7902
# step 9830: train loss 2.5160, val loss 2.4486
# step 9840: train loss 2.4374, val loss 2.5169
# step 9850: train loss 2.5932, val loss 2.5906
# step 9860: train loss 2.4879, val loss 2.5840
# step 9870: train loss 2.4806, val loss 2.4805
# step 9880: train loss 2.5351, val loss 2.5149
# step 9890: train loss 2.4984, val loss 2.5332
# step 9900: train loss 2.5135, val loss 2.4876
# step 9910: train loss 2.5133, val loss 2.5228
# step 9920: train loss 2.5429, val loss 2.5108
# step 9930: train loss 2.4757, val loss 2.5805
# step 9940: train loss 2.5489, val loss 2.5597
# step 9950: train loss 2.5475, val loss 2.5100
# step 9960: train loss 2.5385, val loss 2.5726
# step 9970: train loss 2.5332, val loss 2.5602
# step 9980: train loss 2.5340, val loss 2.5503
# step 9990: train loss 2.4674, val loss 2.5065

# %% [markdown]
# Once the network has been trained for 100 iterations, we can generate a sequence of characters.
#
# #### Questions:
# - What is the effect of training?
# - Increase the number of iterations to 1,000 and then to 10,000. Note the obtained loss and the generated sentence. What do you observe?

# %%
# Create a prompt as a tensor of size (1,1) containing the integer corresponding to the character '\n'
prompt = torch.tensor([[stoi['\n']]], dtype=torch.long).to(device)

# Generate a sequence of 100 characters from this prompt
generated_sequence = m.generate(prompt, max_new_tokens=100)

# Decode the generated sequence to get the string
generated_text = decode(generated_sequence[0].tolist())

print(generated_text)
# Out:
# T
# I6kwÈïÂ:?]G2he_!kême lere fûÀU; q9KT
# Puraièdapr leu nevô:;
#  péapêd,
# Bze, côpours e chirble qur,
# Oç

# %% [markdown]
# after training with 1000 , a see that the model still givin completely non sense sentences , but at least he learns how to move to another line, but with 10000 the model still giving non sense sentences but in a more organized way

# %% [markdown]
# ## Single Head Attention
#
# We will now implement the basic attention mechanism. For each pair of words in the sequence, this mechanism combines:
# - **Q** (*query*): the information being searched for,
# - **K** (*key*): the information retrieved,
# - **V** (*value*): a result vector calculated from the attention mechanism.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masking
#
# However, since we are using the model to generate sequences, we must not use characters that come after the current character—these are precisely the characters we aim to predict during training. *The future should not be used to predict the future.*
#
# To enforce this constraint, we integrate a **masking matrix** into the process. This matrix ensures that:
# - For the first character in the sequence, only that character is available for prediction (no context).
# - For the second character, only the first and second characters can be used.
# - For the third character, only the first three characters are accessible, and so on.
#
# This results in a **lower triangular matrix**, where each row is normalized (rows sum to 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# The [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) function provides another way to achieve normalization.
#
# #### Question:
# - Verify that applying `softmax` results in the same lower triangular matrix.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implementation
#
# We can now implement the attention layer based on the following formula:
#
# ![attention_formula](images/attention_formula.png)
#
# This involves computing the **queries (Q)**, **keys (K)**, and **values (V)**, applying the **masking mechanism**, and using the **softmax function** to normalize the attention scores before computing the weighted sum of values.

# %% [markdown]
# #### Questions:
#
# - Create the **key**, **query**, and **value** layers as linear layers of dimension `C × head_size`.
# - Apply these layers to `x`.
# - Compute the attention weights:
#   ```python
#   weights = query @ key.transpose(-2, -1)
#   ```
#   (Transpose the second and third dimensions of `key` to enable matrix multiplication).
# - Apply the **normalization factor** (typically, divide by `sqrt(head_size)`).
# - Apply the **triangular mask** and the **softmax** function to `weights`.
# - Apply the **value** layer to `x`.
# - Compute the final output:
#   ```python
#   out = weights @ value(x)
#   ```

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)

# define the Key layer  
key = nn.Linear(C, head_size, bias=False)
# define the Query layer
query = nn.Linear(C, head_size, bias=False)
# define the Value layer
value = nn.Linear(C, head_size, bias=False)

# apply each layer to the input
k = key(x)  # (B, T, head_size)
q = query(x)  # (B, T, head_size)
v = value(x)  # (B, T, head_size)

# compute the normalized product between Q and K 
weights = q @ k.transpose(-2, -1) / head_size**0.5  # (B, T, head_size) @ (B, head_size, T) -> (B, T, T)

# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril == 0, float('-inf'))

# apply the softmax
weights = nn.functional.softmax(weights, dim=-1)

out = weights @ v  # (B, T, T) @ (B, T, head_size) -> (B, T, head_size)

# print the result
print(weights[0])
print(out[0])
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2987, 0.7013, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2792, 0.3466, 0.3742, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2338, 0.2957, 0.1302, 0.3403, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.1922, 0.2230, 0.2396, 0.2204, 0.1249, 0.0000, 0.0000, 0.0000],
#         [0.1514, 0.2066, 0.2000, 0.0906, 0.2544, 0.0970, 0.0000, 0.0000],
#         [0.1677, 0.0612, 0.1132, 0.1813, 0.1171, 0.1596, 0.1999, 0.0000],
#         [0.1212, 0.1729, 0.0943, 0.1669, 0.1953, 0.0927, 0.0791, 0.0775]],
#        grad_fn=<SelectBackward0>)
# tensor([[-4.6122e-01,  2.0118e-01, -1.0512e-01,  3.3360e-01, -3.0018e-01,
#          -8.4732e-02, -1.3133e-01, -6.0536e-01,  3.3019e-01, -1.1573e+00,
#           3.7831e-01,  5.3141e-01, -5.7368e-01,  1.1383e+00,  2.1583e-01,
#          -7.6467e-02],
#         [-2.7113e-01, -4.6824e-01,  8.7904e-02,  1.4402e-01, -3.0465e-01,
#           5.1585e-02,  8.2296e-01, -1.1214e+00,  3.6351e-01, -1.8755e-01,
#          -4.5680e-01,  2.4367e-01,  4.7116e-02,  8.4345e-01,  5.8262e-01,
#          -1.9330e-01],
#         [-4.4120e-01, -9.2032e-01, -1.5189e-01,  1.7473e-01, -2.5701e-01,
#          -2.6974e-01,  6.8130e-01, -3.4559e-01,  4.1127e-01, -6.2690e-03,
#          -2.7115e-01,  3.0489e-01,  1.5252e-01,  4.3331e-01,  4.8847e-01,
#           1.4382e-01],
#         [-2.6904e-01, -4.1682e-01, -3.8867e-01,  2.4183e-01, -2.1927e-01,
#           7.8005e-02,  5.6442e-01, -5.4789e-01,  4.7705e-01, -9.9463e-02,
#          -5.3592e-01,  8.3962e-02,  1.6281e-01,  4.0434e-01,  1.9956e-01,
#          -1.4603e-01],
#         [-3.2467e-01, -3.6162e-01, -3.0457e-01,  2.7551e-01, -1.2116e-01,
#          -1.3337e-01,  4.7097e-01, -3.3936e-01,  4.2116e-01, -9.7364e-02,
#          -4.0583e-01,  5.7094e-02,  1.9270e-01,  2.9198e-01,  1.8249e-01,
#           1.1684e-01],
#         [-2.6134e-01, -6.7014e-02, -8.1828e-02,  2.4904e-01,  2.3072e-02,
#          -2.3759e-01,  2.9995e-01, -3.7775e-01,  2.9739e-01, -2.0317e-01,
#          -2.0425e-01, -2.6323e-02,  9.4138e-02,  2.2432e-01,  2.4443e-01,
#           2.0688e-01],
#         [-1.1405e-01, -1.9347e-01, -1.9936e-01,  1.5183e-02, -1.3493e-01,
#          -2.9447e-02,  3.8221e-03, -1.6603e-01,  3.1265e-01, -2.4763e-01,
#           3.4741e-02,  1.9521e-01, -8.3834e-02,  1.2900e-01,  1.6187e-01,
#           8.6166e-04],
#         [-2.2159e-01,  1.8512e-02, -1.8536e-01,  1.2415e-01, -9.9693e-02,
#          -2.0647e-02,  1.5699e-01, -3.4757e-01,  2.8284e-01, -1.3197e-01,
#          -2.4830e-01,  6.4806e-02,  5.8362e-03,  1.8691e-01,  1.6228e-01,
#           2.1354e-02]], grad_fn=<SelectBackward0>)

# %% [markdown]
# ### Questions:
#
# - Copy your code into `gpt_single_head.py`:
#   - Define the **key**, **query**, and **value** layers in the **constructor** of the `Head` class.
#   - Implement the **computations** in the `forward` function.
# - Train the model.
# - What are the **training** and **validation** losses?
# - Does the generated text appear **better** compared to the previous model?

# %% [markdown]
# ## Multi-Head Attention
#
# Multi-head attention is simply the parallel computation of multiple **single-head attention** mechanisms. Each **single-head attention** output is concatenated to form the output of the **multi-head attention** module. In the original paper's illustration, the number of heads in the **multi-head attention** is denoted as `h`.
#
# To allow for **weighted combinations** of each single-head attention output, a **linear transformation layer** is added after concatenation.
#
# ![multi head attention](images/multi_head_attention.png)
#
# #### Questions:
#
# - In the **constructor**, create a list containing `num_heads` instances of the `Head` module using PyTorch’s [`ModuleList`](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html).
# - In the `forward` function:
#   - Apply each **single-head attention** to the input.
#   - Concatenate the results using PyTorch’s [`cat`](https://pytorch.org/docs/stable/generated/torch.cat.html) function.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# #### Questions:
#
# 1. **Copy** the file `gpt_single_head.py` and rename it as `gpt_multi_head.py`.
# 2. **Add** the `MultiHeadAttention` module in `gpt_multi_head.py`.
# 3. At the **beginning of the file**, add a parameter:
#    ```python
#    n_head = 4
#    ```
# 4. In the `BigramLanguageModel` module, **replace** the `Head` module with `MultiHeadAttention`, using the parameters:
#    ```python
#    num_heads = n_head
#    head_size = n_embd // n_head
#    ```
#    This ensures the total number of parameters remains **the same**.
# 5. **Retrain the model** and note:
#    - The total number of **parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802
# ```

# %% [markdown]
# ## Adding a FeedForward Computation Layer
#
# After the **attention layers**, which collect information from the sequence, a **computation layer** is added to combine all the gathered information.
#
# This layer is a simple **Multi-Layer Perceptron (MLP)** with:
# - One **hidden layer**,
# - A **ReLU non-linearity** using [`ReLU`](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
#
# ### Architecture:
#
# <img src="images/multi_ff.png" alt="multi feedforward" width="200">

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# #### Questions:
#
# 1. **Add** the `FeedForward` module to your `gpt_multi_head.py` file.
# 2. **Integrate** this `FeedForward` layer **after** the **multi-head attention** module.
# 3. **Retrain the model** and note:
#    - The total **number of parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216
# ```

# %% [markdown]
# ## Stacking Blocks
#
# The network we have built so far represents just **one block** of the final model. Now, we can **stack multiple blocks** of **multi-head attention** to create a **deeper** network.
#
# ### Architecture:
# ![multi feedforward](images/multi_bloc.png)
#
# The following code defines a **block**:

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# #### Questions:
#
# - Add the `Block` module to `gpt_multi_head.py`.
# - Modify the `BigramLanguageModel` code to include **three** instances of `Block(n_embd, n_head=4)`, using a [`Sequential`](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) container **instead of** `MultiHeadAttention` and `FeedForward`.
# - Retrain the model and note:
#   - The **number of parameters**
#   - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213
# ```

# %% [markdown]
# ## Improving Training
#
# If we want to continue increasing the **network size**, we need to incorporate layers that **enhance training stability** and **improve generalization** (reducing overfitting). These layers include:
#
# - **Skip connections** (or **residual connections**)
# - **Normalization layers**
# - **Dropout**
#
# ### Updated Architecture:
#
# <img src="images/multi_skip_norm.png" alt="multi feedforward" width="200">
#
# ---
#
# #### Questions:
#
# 1. In the `Block` module, **add a skip connection** by summing the input at each step:
#    ```python
#    x = x + self.sa(self.ln1(x))
#    x = x + self.ffwd(self.ln2(x))
#    ```
#
# 2. In the `Block` module, **add two** [`LayerNorm`](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) layers of size `n_embd`:
#    - **Before** the `Multi-Head Attention` layer.
#    - **Before** the `FeedForward` layer.
#
# 3. **After the sequence of 3 blocks**, add a **LayerNorm** layer of size `n_embd`.
#
# 4. Define a variable at the **beginning of the file**:
#    ```python
#    dropout = 0.2
#    ```
#    Then add a [`Dropout`](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) layer:
#    - **After** the `ReLU` activation in `FeedForward`.
#    - **After** the `Multi-Head Attention` layer in `MultiHeadAttention`.
#    - **After** the `softmax` layer in the single-head attention `Head`.
#
# 5. **Retrain the model** and note:
#    - The **number of parameters**
#    - The **training** and **validation** losses
#
# ---
#
# **Expected Output Example:**
# ```
# 0.019653 M parameters
# ```

# %% [markdown]
# ## Conclusion
#
# The key components of **GPT-2** are now in place. The next step is to **scale up** the model and train it on a **much larger** dataset. For comparison, the parameters of [GPT-2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) are:
#
# - **`vocab_size = 50257`** → GPT-2 models **subword tokens**, while we model **characters**. For us, `vocab_size = 100`.
# - **`n_positions = 1024`** → The maximum **context size**. For us, it's `block_size = 8`.
# - **`n_embd = 768`** → The **embedding dimension**. For us, it's `n_embd = 32`.
# - **`n_layer = 12`** → The number of **blocks**. For us, it's `3`.
# - **`n_head = 12`** → The number of **multi-head attention layers**. For us, it's `4`.
#
# Overall, **GPT-2** consists of **1.5 billion parameters** and was trained on **8 million web pages**, totaling **40 GB of text**.
#
# ---
#
# ### **Training Results**
# ```text
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
# ```
#
# ### **Generated Text Sample:**
#
# ```text
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
